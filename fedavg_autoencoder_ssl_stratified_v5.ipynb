# %% [markdown]
# v2 - UCI HAR dataset

# %% [markdown]
# # Setup

# %%
# import libraries
import os
import sys
import time
import pandas as pd
import numpy as np
from scipy import stats
import copy
from scipy.interpolate import CubicSpline
import torch.optim as optim
import torch.nn as nn
import torch
from torch.optim import Adam
from scipy.fftpack import fft, ifft
from scipy.stats import mode
from torch.utils.data import DataLoader, TensorDataset
import datetime
from sklearn.metrics import f1_score

# %% [markdown]
# ## Hyperparameters

# %%
num_epochs = 200
batch_size = 32  # Set your batch size
learning_rate_client = 0.01
local_epochs = 5
subject_dir = 'FL_Data/windowed_data_filtered_v5/subject_'  # Set your directory to the subject data
numclients = 90
num_classes = 10

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

#current timestamp
current_time = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

# %%
# set the seed
torch.manual_seed(420)
np.random.seed(420)

# %% [markdown]
# # Load Data

# %%
def load_data_client(id, batch_size=batch_size, type='labelled_train'):
    # Load the data
    data = np.load(subject_dir + str(id) + '/windowed_' + type + '_x.npy')
    labels = np.load(subject_dir + str(id) + '/windowed_' + type + '_y.npy')

    # print shape of data
    # print(data.shape)
    # print(labels.shape)

    # Convert to torch tensor
    data = torch.from_numpy(data).float()
    labels = torch.from_numpy(labels).long()

    # Create a dataset
    dataset = torch.utils.data.TensorDataset(data, labels)

    # Create a dataloader
    if type == 'labelled_train' or type == 'unlabelled_train':
        dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
    else:
        dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=False)
    
    return dataloader

# %%
# for i in range(54):
#     data_label_train = load_data_client(i, batch_size, 'labelled_train')
#     data_unlabel_train = load_data_client(i, batch_size, 'unlabelled_train')
#     data_test = load_data_client(i, batch_size, 'test')

# %% [markdown]
# # Model Architecture

# %%
import torch
import torch.nn as nn

class PoolingAutoEncoder(nn.Module):
    def __init__(self, input_channels=3, sequence_length=128):
        super(PoolingAutoEncoder, self).__init__()
        
        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv1d(in_channels=input_channels, out_channels=32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),  # Adding pooling layer
            nn.Conv1d(32, 64, 5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool1d(2, 2),  # Adding pooling layer
            nn.Conv1d(64, 128, 5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool1d(2, 2),  # Adding pooling layer
        )
        
        # Adjusted for pooling layers
        self.flat_features = self._get_flat_features(input_channels, sequence_length)
        
        # Latent space
        self.latent_space = nn.Linear(self.flat_features, 128)  # Project to a 128-dimensional latent space

        # Decoder
        self.decoder = nn.Sequential(
            nn.ConvTranspose1d(128, 128, 5, stride=2, padding=2, output_padding=1),  # Adjust stride for upsampling
            nn.ReLU(),
            nn.ConvTranspose1d(128, 64, 5, stride=2, padding=2, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose1d(64, 32, 5, stride=2, padding=2, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose1d(32, input_channels, 5, stride=1, padding=2),  # Output channels = input channels
            nn.Sigmoid(),  # Assuming the input data is normalized between 0 and 1
        )
        
    def _get_flat_features(self, input_channels, sequence_length):
        # Temporarily override self.encoder with self.encoder[:3] to include only up to the first pooling layer
        tmp_encoder = nn.Sequential(*list(self.encoder.children())[:3])
        x = torch.randn(1, input_channels, sequence_length)
        x = tmp_encoder(x)
        return x.numel()

    def forward(self, x):
        x = self.encoder(x)
        x = x.view(x.size(0), -1)  # Flatten for linear layer
        x = self.latent_space(x)
        x = x.view(x.size(0), 128, -1)  # Reshape for decoder, adjust based on the actual size after flattening
        x = self.decoder(x)
        return x

# Example instantiation of the model
# model = PoolingAutoEncoder(input_channels=3, sequence_length=128)
# print(model)

# %%
class HARAutoEncoder(nn.Module):
    def __init__(self, input_channels=3, sequence_length=128):
        super(HARAutoEncoder, self).__init__()
        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv1d(in_channels=input_channels, out_channels=32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.Conv1d(32, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.Conv1d(32, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.Conv1d(32, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
        )
        flattened_size = 32 * sequence_length  # Adjust based on the actual architecture
        self.fc_encoder = nn.Linear(flattened_size, 128)

        # Decoder
        self.fc_decoder = nn.Linear(128, flattened_size)
        self.decoder = nn.Sequential(
            nn.ConvTranspose1d(32, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.ConvTranspose1d(32, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.ConvTranspose1d(32, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.ConvTranspose1d(32, input_channels, kernel_size=5, stride=1, padding=2),
            nn.Sigmoid(),
        )

    def forward(self, x):
        x = self.encoder(x)
        x = x.view(-1, 32 * 128)  # Adjust based on the actual architecture
        x = self.fc_encoder(x)
        x = self.fc_decoder(x)
        x = x.view(-1, 32, 128)  # Adjust based on the actual architecture
        x = self.decoder(x)
        return x

# %% [markdown]
# # Train and Test Function

# %%
def train_autoencoder(model, train_loader, device, learning_rate=0.01, epochs=5):
    model.to(device)
    criterion = nn.MSELoss()
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    
    model.train()
    total_loss = 0
    for epoch in range(epochs):
        for data, target in train_loader:
            data, target = data.to(device), target.to(device)
            # print(data.shape)
            data = data.permute(0, 2, 1)
            optimizer.zero_grad()
            output = model(data)
            # print(output.shape)
            loss = criterion(output, data)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        
        epoch_loss = total_loss / len(train_loader)
        # print(f'Epoch {epoch+1}, Loss: {epoch_loss}')
        total_loss = 0  # Reset total loss for the next epoch

    results = {
        'train_loss': epoch_loss
    }
    
    return results  # Returns the average loss of the last epoch

# %%
def test_autoencoder(model, test_loader, device):
    model.to(device)
    model.eval()
    
    criterion = nn.MSELoss()
    total_loss = 0
    
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            data = data.permute(0, 2, 1)
            output = model(data)
            loss = criterion(output, data)
            total_loss += loss.item()
    
    avg_loss = total_loss / len(test_loader)
    # print(f'Test Loss: {avg_loss}')
    
    return avg_loss  # Returns the average loss for the test data

# %% [markdown]
# # Client

# %%
class Client():
  def __init__(self, client_config:dict):
    # client config as dict to make configuration dynamic
    self.id = client_config["id"]
    self.config = client_config
    self.__model = None

    self.labelled_loader = self.config["labelled"]
    self.unlabelled_loader = self.config["unlabelled"]
    self.test_loader = self.config["test"]

  @property
  def model(self):
    return self.__model

  @model.setter
  def model(self, model):
    self.__model = model

  def __len__(self):
    """Return a total size of the client's local data."""
    return len(self.unlabelled_loader.sampler)

  def train_ssl(self):
    results = train_autoencoder(model = self.model,
                    train_loader = self.unlabelled_loader,
                    device=device,
                    learning_rate=learning_rate_client,
                    epochs=local_epochs)
    print(f"Train result client {self.id}: {results}")

  def test_ssl(self):
    loss = test_autoencoder(model = self.model,
                    test_loader = self.test_loader,
                    device=device)
    print(f"Test result client {self.id}: {loss}")
    return loss

# %% [markdown]
# # Server

# %%
class FedAvg():
  def __init__(self):
    self.globalmodel = HARAutoEncoder(input_channels=3, sequence_length=128)
    self.rounds = 0
    self.params = {}

  def aggregate(self, round):
    #v1:update the aggregate to save the model with round and date indicator
    modelparams = []
    for i in self.params.keys():
      modelparams.append(self.params[i])

    avg_weights = {}
    for name in modelparams[0].keys():
      avg_weights[name] = torch.mean(torch.stack([w[name] for w in modelparams]), dim = 0)

    self.globalmodel.load_state_dict(avg_weights)
    
    #save the model
    name_path = f'AutoEncoder_FL/Model_Global_Filtered_v5/{current_time}'
    if not os.path.exists(name_path):
      os.makedirs(name_path)

    torch.save(self.globalmodel.state_dict(), f"{name_path}/global_model_round_{round}.pth")
    
    # filename = f"{path_glob_m}/global_model_round_{round}_{current_time}.pth"
    # torch.save(self.globalmodel.state_dict(), filename)

  def clientstrain(self, clientconfig):
    clients = clientconfig
    for i in clients.keys():
      test_client = Client(clients[i])
      test_client.model = copy.deepcopy(self.globalmodel)
      test_client.train_ssl()
      test_client.test_ssl()
      self.params[i] = test_client.model.state_dict()

  def initiate_FL(self, clientconfig, serverdata):
    clients = clientconfig
    print("Round: {}".format(self.rounds))

    print("Obtaining Weights!!")
    self.clientstrain(clients)

    #### Aggregate model
    print("Aggregating Model!!")
    self.aggregate(self.rounds)

    #### Replace parameters with global model parameters
    for i in self.params.keys():
        self.params[i] = self.globalmodel.state_dict()


    servertest = serverdata
    loss = test_autoencoder(model = self.globalmodel,
                    test_loader = servertest,
                    device=device)
    print("Round {} metrics:".format(self.rounds))
    print("Server Loss = {}".format(loss))
    print("Round {} finished!".format(self.rounds))
    self.rounds += 1
    return clients, loss

# %% [markdown]
# # Main

# %%
clients = {}

for i in range(numclients):
    clients[i] = {"id": i, "batch_size": batch_size, "local_epoch": 5}
    clients[i]['labelled'] = load_data_client(i, batch_size, 'labelled_train')
    clients[i]['unlabelled'] = load_data_client(i, batch_size, 'unlabelled_train')
    clients[i]['test'] = load_data_client(i, batch_size, 'test')

    print(f"client: {i}")
    print(f"labelled: {len(clients[i]['labelled'])}")
    print(f"unlabelled: {len(clients[i]['unlabelled'])}")
    print(f"test: {len(clients[i]['test'])}")

# combine all client test data into one
combined_test_data = []
combined_test_labels = []
for i in range(numclients):
    for data, labels in clients[i]['test']:
        combined_test_data.append(data)
        combined_test_labels.append(labels)
combined_test_data = torch.cat(combined_test_data, dim=0)
combined_test_labels = torch.cat(combined_test_labels, dim=0)
# create dataset and dataloader
combined_test_dataset = torch.utils.data.TensorDataset(combined_test_data, combined_test_labels)
combined_test_dataloader = torch.utils.data.DataLoader(combined_test_dataset, batch_size=batch_size, shuffle=False)

print(f"combined test: {len(combined_test_dataloader)}")

# server test_data
server_test_data = combined_test_dataloader

server = FedAvg()

start = time.time()
loss_rounds = []
for i in range(num_epochs):
    clients, loss = server.initiate_FL(clientconfig=clients, serverdata=server_test_data)
    loss_rounds.append(loss)

print("\n")
print("-" * 50)
print("Loss values all rounds: ", loss_rounds)

print(f"\nTime cost: {round((time.time()-start)/60, 2)}min.")
# Out:
# client: 0
# labelled: 18
# unlabelled: 70
# test: 22
# client: 1
# labelled: 17
# unlabelled: 67
# test: 21
# client: 2
# labelled: 18
# unlabelled: 71
# test: 22
# client: 3
# labelled: 16
# unlabelled: 63
# test: 20
# client: 4
# labelled: 20
# unlabelled: 79
# test: 25
# client: 5
# labelled: 19
# unlabelled: 76
# test: 24
# client: 6
# labelled: 5
# unlabelled: 19
# test: 6
# client: 7
# labelled: 5
# unlabelled: 20
# test: 7
# client: 8
# labelled: 3
# unlabelled: 12
# test: 4
# client: 9
# labelled: 17
# unlabelled: 68
# test: 21
# client: 10
# labelled: 14
# unlabelled: 53
# test: 17
# client: 11
# labelled: 18
# unlabelled: 72
# test: 23
# client: 12
# labelled: 17
# unlabelled: 65
# test: 21
# client: 13
# labelled: 20
# unlabelled: 77
# test: 24
# client: 14
# labelled: 17
# unlabelled: 68
# test: 22
# client: 15
# labelled: 15
# unlabelled: 60
# test: 19
# client: 16
# labelled: 19
# unlabelled: 77
# test: 24
# client: 17
# labelled: 18
# unlabelled: 71
# test: 22
# client: 18
# labelled: 17
# unlabelled: 66
# test: 21
# client: 19
# labelled: 18
# unlabelled: 69
# test: 22
# client: 20
# labelled: 17
# unlabelled: 67
# test: 21
# client: 21
# labelled: 18
# unlabelled: 69
# test: 22
# client: 22
# labelled: 14
# unlabelled: 56
# test: 18
# client: 23
# labelled: 18
# unlabelled: 70
# test: 22
# client: 24
# labelled: 2
# unlabelled: 8
# test: 3
# client: 25
# labelled: 2
# unlabelled: 7
# test: 3
# client: 26
# labelled: 2
# unlabelled: 8
# test: 3
# client: 27
# labelled: 2
# unlabelled: 8
# test: 3
# client: 28
# labelled: 2
# unlabelled: 7
# test: 3
# client: 29
# labelled: 2
# unlabelled: 8
# test: 3
# client: 30
# labelled: 2
# unlabelled: 7
# test: 3
# client: 31
# labelled: 2
# unlabelled: 7
# test: 2
# client: 32
# labelled: 2
# unlabelled: 7
# test: 3
# client: 33
# labelled: 2
# unlabelled: 7
# test: 3
# client: 34
# labelled: 2
# unlabelled: 8
# test: 3
# client: 35
# labelled: 2
# unlabelled: 8
# test: 3
# client: 36
# labelled: 2
# unlabelled: 8
# test: 3
# client: 37
# labelled: 2
# unlabelled: 8
# test: 3
# client: 38
# labelled: 2
# unlabelled: 8
# test: 3
# client: 39
# labelled: 2
# unlabelled: 9
# test: 3
# client: 40
# labelled: 3
# unlabelled: 9
# test: 3
# client: 41
# labelled: 3
# unlabelled: 9
# test: 3
# client: 42
# labelled: 2
# unlabelled: 9
# test: 3
# client: 43
# labelled: 2
# unlabelled: 8
# test: 3
# client: 44
# labelled: 3
# unlabelled: 10
# test: 3
# client: 45
# labelled: 2
# unlabelled: 8
# test: 3
# client: 46
# labelled: 3
# unlabelled: 9
# test: 3
# client: 47
# labelled: 3
# unlabelled: 9
# test: 3
# client: 48
# labelled: 3
# unlabelled: 10
# test: 3
# client: 49
# labelled: 3
# unlabelled: 9
# test: 3
# client: 50
# labelled: 3
# unlabelled: 9
# test: 3
# client: 51
# labelled: 3
# unlabelled: 9
# test: 3
# client: 52
# labelled: 2
# unlabelled: 8
# test: 3
# client: 53
# labelled: 3
# unlabelled: 9
# test: 3
# client: 54
# labelled: 9
# unlabelled: 33
# test: 11
# client: 55
# labelled: 7
# unlabelled: 26
# test: 8
# client: 56
# labelled: 10
# unlabelled: 38
# test: 12
# client: 57
# labelled: 3
# unlabelled: 13
# test: 4
# client: 58
# labelled: 8
# unlabelled: 31
# test: 10
# client: 59
# labelled: 8
# unlabelled: 30
# test: 10
# client: 60
# labelled: 9
# unlabelled: 34
# test: 11
# client: 61
# labelled: 11
# unlabelled: 44
# test: 14
# client: 62
# labelled: 4
# unlabelled: 14
# test: 5
# client: 63
# labelled: 10
# unlabelled: 38
# test: 12
# client: 64
# labelled: 9
# unlabelled: 34
# test: 11
# client: 65
# labelled: 9
# unlabelled: 35
# test: 11
# client: 66
# labelled: 10
# unlabelled: 38
# test: 12
# client: 67
# labelled: 11
# unlabelled: 42
# test: 13
# client: 68
# labelled: 7
# unlabelled: 26
# test: 8
# client: 69
# labelled: 5
# unlabelled: 20
# test: 7
# client: 70
# labelled: 6
# unlabelled: 24
# test: 8
# client: 71
# labelled: 8
# unlabelled: 33
# test: 11
# client: 72
# labelled: 9
# unlabelled: 36
# test: 12
# client: 73
# labelled: 14
# unlabelled: 55
# test: 18
# client: 74
# labelled: 7
# unlabelled: 26
# test: 8
# client: 75
# labelled: 6
# unlabelled: 25
# test: 8
# client: 76
# labelled: 7
# unlabelled: 28
# test: 9
# client: 77
# labelled: 7
# unlabelled: 28
# test: 9
# client: 78
# labelled: 4
# unlabelled: 15
# test: 5
# client: 79
# labelled: 9
# unlabelled: 36
# test: 11
# client: 80
# labelled: 9
# unlabelled: 34
# test: 11
# client: 81
# labelled: 6
# unlabelled: 24
# test: 8
# client: 82
# labelled: 10
# unlabelled: 38
# test: 12
# client: 83
# labelled: 7
# unlabelled: 26
# test: 9
# client: 84
# labelled: 12
# unlabelled: 48
# test: 15
# client: 85
# labelled: 9
# unlabelled: 33
# test: 11
# client: 86
# labelled: 8
# unlabelled: 32
# test: 10
# client: 87
# labelled: 10
# unlabelled: 39
# test: 13
# client: 88
# labelled: 6
# unlabelled: 24
# test: 8
# client: 89
# labelled: 9
# unlabelled: 34
# test: 11
# combined test: 878
# Round: 0
# Obtaining Weights!!
# Train result client 0: {'train_loss': 0.7128545488630023}
# Test result client 0: 0.7117977955124595
# Train result client 1: {'train_loss': 0.7877647405240074}
# Test result client 1: 0.7784519451005119
# Train result client 2: {'train_loss': 0.770914290152805}
# Test result client 2: 0.7503520846366882
# Train result client 3: {'train_loss': 0.7525706745329357}
# Test result client 3: 0.7398459613323212
# Train result client 4: {'train_loss': 0.6102748505676849}
# Test result client 4: 0.612432427406311
# Train result client 5: {'train_loss': 0.7593401929265574}
# Test result client 5: 0.7555296818415324
# Train result client 6: {'train_loss': 1.3910917796586688}
# Test result client 6: 1.36051611105601
# Train result client 7: {'train_loss': 0.8396750181913376}
# Test result client 7: 0.8285595774650574
# Train result client 8: {'train_loss': 1.714568207661311}
# Test result client 8: 1.6943487226963043
# Train result client 9: {'train_loss': 0.9657072310938555}
# Test result client 9: 0.9602675494693574
# Train result client 10: {'train_loss': 0.9090668424120489}
# Test result client 10: 0.8937840987654293
# Train result client 11: {'train_loss': 0.8130347695615556}
# Test result client 11: 0.8116973768109861
# Train result client 12: {'train_loss': 1.0506133996523344}
# Test result client 12: 1.0403929295993986
# Train result client 13: {'train_loss': 0.9663753819156002}
# Test result client 13: 0.9514934743444124
# Train result client 14: {'train_loss': 1.0860291333759533}
# Test result client 14: 1.0673454214226117
# Train result client 15: {'train_loss': 0.9265840232372284}
# Test result client 15: 0.9131932729168942
# Train result client 16: {'train_loss': 0.9948029703908152}
# Test result client 16: 0.9874480962753296
# Train result client 17: {'train_loss': 0.9150202635308387}
# Test result client 17: 0.9027609174901788
# Train result client 18: {'train_loss': 1.1626042850089795}
# Test result client 18: 1.1638214474632627
# Train result client 19: {'train_loss': 0.9402766443681025}
# Test result client 19: 0.9338880343870684
# Train result client 20: {'train_loss': 1.000711810232988}
# Test result client 20: 0.9909934032531011
# Train result client 21: {'train_loss': 0.9873930906903916}
# Test result client 21: 0.98373636061495
# Train result client 22: {'train_loss': 1.2235984546797616}
# Test result client 22: 1.2133764889505174
# Train result client 23: {'train_loss': 1.0789040769849505}
# Test result client 23: 1.0780463489619168
# Train result client 24: {'train_loss': 0.30325522273778915}
# Test result client 24: 0.2995450794696808
# Train result client 25: {'train_loss': 0.3046348180089678}
# Test result client 25: 0.30181969205538434
# Train result client 26: {'train_loss': 0.30271750316023827}
# Test result client 26: 0.2994166413942973
# Train result client 27: {'train_loss': 0.28293753042817116}
# Test result client 27: 0.27998024225234985
# Train result client 28: {'train_loss': 0.2941854212965284}
# Test result client 28: 0.29029767711957294
# Train result client 29: {'train_loss': 0.3009524643421173}
# Test result client 29: 0.2978108326594035
# Train result client 30: {'train_loss': 0.31182481561388287}
# Test result client 30: 0.30713626742362976
# Train result client 31: {'train_loss': 0.3031094712870462}
# Test result client 31: 0.30015332996845245
# Train result client 32: {'train_loss': 0.3031039237976074}
# Test result client 32: 0.30101630091667175
# Train result client 33: {'train_loss': 0.3085453084536961}
# Test result client 33: 0.3059211273988088
# Train result client 34: {'train_loss': 0.28760799020528793}
# Test result client 34: 0.28458550572395325
# Train result client 35: {'train_loss': 0.30166804790496826}
# Test result client 35: 0.298376868168513
# Train result client 36: {'train_loss': 0.3055047132074833}
# Test result client 36: 0.3020818034807841
# Train result client 37: {'train_loss': 0.33322369679808617}
# Test result client 37: 0.331101914246877
# Train result client 38: {'train_loss': 0.2969103045761585}
# Test result client 38: 0.2937252124150594
# Train result client 39: {'train_loss': 0.3038755754629771}
# Test result client 39: 0.3007862667242686
# Train result client 40: {'train_loss': 0.3072684473461575}
# Test result client 40: 0.3035662571589152
# Train result client 41: {'train_loss': 0.29370010561413235}
# Test result client 41: 0.2904809315999349
# Train result client 42: {'train_loss': 0.28131359153323704}
# Test result client 42: 0.27802129586537677
# Train result client 43: {'train_loss': 0.2995261587202549}
# Test result client 43: 0.2958584129810333
# Train result client 44: {'train_loss': 0.3048793762922287}
# Test result client 44: 0.30099015434583026
# Train result client 45: {'train_loss': 0.2840036153793335}
# Test result client 45: 0.27996590733528137
# Train result client 46: {'train_loss': 0.30043696694903904}
# Test result client 46: 0.2971544663111369
# Train result client 47: {'train_loss': 0.29412279857529533}
# Test result client 47: 0.2903124988079071
# Train result client 48: {'train_loss': 0.27254366874694824}
# Test result client 48: 0.26936129728953045
# Train result client 49: {'train_loss': 0.2749529745843675}
# Test result client 49: 0.27188695470492047
# Train result client 50: {'train_loss': 0.29008788532680935}
# Test result client 50: 0.28619613250096637
# Train result client 51: {'train_loss': 0.3190889126724667}
# Test result client 51: 0.3158341348171234
# Train result client 52: {'train_loss': 0.2792583145201206}
# Test result client 52: 0.27510184049606323
# Train result client 53: {'train_loss': 0.2810656693246629}
# Test result client 53: 0.2778562307357788
# Train result client 54: {'train_loss': 1.4201804002126057}
# Test result client 54: 1.4199920242482966
# Train result client 55: {'train_loss': 1.280181884765625}
# Test result client 55: 1.2876502722501755
# Train result client 56: {'train_loss': 1.1447579076415615}
# Test result client 56: 1.1437338491280873
# Train result client 57: {'train_loss': 1.242155331831712}
# Test result client 57: 1.2357449531555176
# Train result client 58: {'train_loss': 0.5551800054888572}
# Test result client 58: 0.5532478511333465
# Train result client 59: {'train_loss': 1.0946566462516785}
# Test result client 59: 1.0816063165664673
# Train result client 60: {'train_loss': 1.2334382569088655}
# Test result client 60: 1.2212624008005315
# Train result client 61: {'train_loss': 1.2106542641466314}
# Test result client 61: 1.2024696043559484
# Train result client 62: {'train_loss': 0.7064142950943538}
# Test result client 62: 0.6995488047599793
# Train result client 63: {'train_loss': 1.2945818148161237}
# Test result client 63: 1.2794570128122966
# Train result client 64: {'train_loss': 0.8748973853447858}
# Test result client 64: 0.8579262061552568
# Train result client 65: {'train_loss': 1.154951364653451}
# Test result client 65: 1.142741864377802
# Train result client 66: {'train_loss': 1.0119785195902775}
# Test result client 66: 1.0055091679096222
# Train result client 67: {'train_loss': 1.2792081435521443}
# Test result client 67: 1.2652603571231549
# Train result client 68: {'train_loss': 1.1835514719669635}
# Test result client 68: 1.1806229501962662
# Train result client 69: {'train_loss': 0.7069813281297683}
# Test result client 69: 0.7074583853994098
# Train result client 70: {'train_loss': 0.6014508431156477}
# Test result client 70: 0.5960925668478012
# Train result client 71: {'train_loss': 1.1989129239862615}
# Test result client 71: 1.1912308714606545
# Train result client 72: {'train_loss': 1.1937291887071397}
# Test result client 72: 1.2004027366638184
# Train result client 73: {'train_loss': 0.8229646130041642}
# Test result client 73: 0.8169655799865723
# Train result client 74: {'train_loss': 0.45258788764476776}
# Test result client 74: 0.4547087326645851
# Train result client 75: {'train_loss': 0.6497104144096375}
# Test result client 75: 0.6415770202875137
# Train result client 76: {'train_loss': 1.8234248076166426}
# Test result client 76: 1.8085555367999606
# Train result client 77: {'train_loss': 1.8119817887033736}
# Test result client 77: 1.805254128244188
# Train result client 78: {'train_loss': 1.284471050898234}
# Test result client 78: 1.275913906097412
# Train result client 79: {'train_loss': 1.4954062865840063}
# Test result client 79: 1.4876964634115046
# Train result client 80: {'train_loss': 1.3064271877793705}
# Test result client 80: 1.296818115494468
# Train result client 81: {'train_loss': 0.3557522880534331}
# Test result client 81: 0.34936290606856346
# Train result client 82: {'train_loss': 0.8899333131940741}
# Test result client 82: 0.8795694957176844
# Train result client 83: {'train_loss': 1.8718599172738881}
# Test result client 83: 1.7836592064963446
# Train result client 84: {'train_loss': 0.9411964217821757}
# Test result client 84: 0.9320682724316914
# Train result client 85: {'train_loss': 1.145357457074252}
# Test result client 85: 1.1157857504757969
# Train result client 86: {'train_loss': 0.5088006509467959}
# Test result client 86: 0.5095928102731705
# Train result client 87: {'train_loss': 1.0720273164602427}
# Test result client 87: 1.0508796343436608
# Train result client 88: {'train_loss': 0.687418575088183}
# Test result client 88: 0.6872969269752502
# Train result client 89: {'train_loss': 0.6776547484538135}
# Test result client 89: 0.665545024655082
# Aggregating Model!!
# Round 0 metrics:
# Server Loss = 1.1738344299222994
# Round 0 finished!
# Round: 1
# Obtaining Weights!!
# Train result client 0: {'train_loss': 0.703760654585702}
# Test result client 0: 0.7060178301551125
# Train result client 1: {'train_loss': 0.7740025048825279}
# Test result client 1: 0.7696856657663981
# Train result client 2: {'train_loss': 0.7411480226986845}
# Test result client 2: 0.732025452635505
# Train result client 3: {'train_loss': 0.7083222932285733}
# Test result client 3: 0.7093832075595856
# Train result client 4: {'train_loss': 0.6064149782627444}
# Test result client 4: 0.6088584113121033
# Train result client 5: {'train_loss': 0.7479936582477469}
# Test result client 5: 0.7478098049759865
# Train result client 6: {'train_loss': 1.0816005782077187}
# Test result client 6: 1.0419163505236309
# Train result client 7: {'train_loss': 0.7606675237417221}
# Test result client 7: 0.7393439326967511
# Train result client 8: {'train_loss': 1.4452595015366871}
# Test result client 8: 1.407250314950943
# Train result client 9: {'train_loss': 0.9480297837187263}
# Test result client 9: 0.9498221391723269
# Train result client 10: {'train_loss': 0.8767398843225443}
# Test result client 10: 0.8720272569095388
# Train result client 11: {'train_loss': 0.801592678659492}
# Test result client 11: 0.8036039886267289
# Train result client 12: {'train_loss': 1.0217860964628367}
# Test result client 12: 1.0223504106203716
# Train result client 13: {'train_loss': 0.9588479523534899}
# Test result client 13: 0.9466093083222707
# Train result client 14: {'train_loss': 1.0746976768269259}
# Test result client 14: 1.06031042879278
# Train result client 15: {'train_loss': 0.9037526428699494}
# Test result client 15: 0.8974288827494571
# Train result client 16: {'train_loss': 0.9874026666988026}
# Test result client 16: 0.982148344318072
# Train result client 17: {'train_loss': 0.9061985880556241}
# Test result client 17: 0.896357311443849
# Train result client 18: {'train_loss': 1.1467792771079324}
# Test result client 18: 1.1535809607732863
# Train result client 19: {'train_loss': 0.9268218166586282}
# Test result client 19: 0.924912915988402
# Train result client 20: {'train_loss': 0.9806761118903089}
# Test result client 20: 0.978386986823309
# Train result client 21: {'train_loss': 0.9752886865449988}
# Test result client 21: 0.9765200804580342
# Train result client 22: {'train_loss': 1.1972921235220773}
# Test result client 22: 1.1970533463690016
# Train result client 23: {'train_loss': 1.0658364755766732}
# Test result client 23: 1.0695482058958574
# Train result client 24: {'train_loss': 0.21957849338650703}
# Test result client 24: 0.21489813923835754
# Train result client 25: {'train_loss': 0.2214312446968896}
# Test result client 25: 0.21786683797836304
# Train result client 26: {'train_loss': 0.21911618672311306}
# Test result client 26: 0.21480585634708405
# Train result client 27: {'train_loss': 0.20227787271142006}
# Test result client 27: 0.19873312612374625
# Train result client 28: {'train_loss': 0.21332055756023952}
# Test result client 28: 0.2089660863081614
# Train result client 29: {'train_loss': 0.2177409790456295}
# Test result client 29: 0.21344843010107675
# Train result client 30: {'train_loss': 0.22836099352155412}
# Test result client 30: 0.22307714819908142
# Train result client 31: {'train_loss': 0.22084703615733556}
# Test result client 31: 0.21719495952129364
# Train result client 32: {'train_loss': 0.22064379921981267}
# Test result client 32: 0.21787052353223166
# Train result client 33: {'train_loss': 0.2249477675982884}
# Test result client 33: 0.22167101005713144
# Train result client 34: {'train_loss': 0.20634960755705833}
# Test result client 34: 0.20250325898329416
# Train result client 35: {'train_loss': 0.218333438038826}
# Test result client 35: 0.21418975293636322
# Train result client 36: {'train_loss': 0.22150259651243687}
# Test result client 36: 0.21718748410542807
# Train result client 37: {'train_loss': 0.24582655914127827}
# Test result client 37: 0.24161857863267264
# Train result client 38: {'train_loss': 0.2145185749977827}
# Test result client 38: 0.21029201646645865
# Train result client 39: {'train_loss': 0.21870483292473686}
# Test result client 39: 0.21406164268652597
# Train result client 40: {'train_loss': 0.22177845239639282}
# Test result client 40: 0.21644249061743417
# Train result client 41: {'train_loss': 0.21018648147583008}
# Test result client 41: 0.20544102787971497
# Train result client 42: {'train_loss': 0.19924122095108032}
# Test result client 42: 0.19435379902521768
# Train result client 43: {'train_loss': 0.21594073250889778}
# Test result client 43: 0.2113463431596756
# Train result client 44: {'train_loss': 0.2172756552696228}
# Test result client 44: 0.21148178974787393
# Train result client 45: {'train_loss': 0.20271855406463146}
# Test result client 45: 0.19815509021282196
# Train result client 46: {'train_loss': 0.21616091661983067}
# Test result client 46: 0.2111944556236267
# Train result client 47: {'train_loss': 0.21066730552249485}
# Test result client 47: 0.20556503037611643
# Train result client 48: {'train_loss': 0.19056232422590255}
# Test result client 48: 0.18571439385414124
# Train result client 49: {'train_loss': 0.19403679337766436}
# Test result client 49: 0.18980005383491516
# Train result client 50: {'train_loss': 0.20679995086457995}
# Test result client 50: 0.20174650847911835
# Train result client 51: {'train_loss': 0.23108012477556863}
# Test result client 51: 0.22593926390012106
# Train result client 52: {'train_loss': 0.1993623673915863}
# Test result client 52: 0.1945228079954783
# Train result client 53: {'train_loss': 0.1995004266500473}
# Test result client 53: 0.1949800749619802
# Train result client 54: {'train_loss': 1.348134412909999}
# Test result client 54: 1.3483579483899204
# Train result client 55: {'train_loss': 1.1706446134127104}
# Test result client 55: 1.1740145683288574
# Train result client 56: {'train_loss': 1.0815059981848065}
# Test result client 56: 1.0769286751747131
# Train result client 57: {'train_loss': 1.1709418755311232}
# Test result client 57: 1.160721242427826
# Train result client 58: {'train_loss': 0.5474202036857605}
# Test result client 58: 0.5422162771224975
# Train result client 59: {'train_loss': 1.0574651082356772}
# Test result client 59: 1.0427252233028412
# Train result client 60: {'train_loss': 1.1887335672098047}
# Test result client 60: 1.1784613891081377
# Train result client 61: {'train_loss': 1.1707552454688332}
# Test result client 61: 1.1607218895639693
# Train result client 62: {'train_loss': 0.7015155894415719}
# Test result client 62: 0.6932382464408875
# Train result client 63: {'train_loss': 1.1408947267030414}
# Test result client 63: 1.1288272539774578
# Train result client 64: {'train_loss': 0.7876063795650706}
# Test result client 64: 0.7627549442377958
# Train result client 65: {'train_loss': 1.0945761169706072}
# Test result client 65: 1.0784368298270486
# Train result client 66: {'train_loss': 0.9424758757415571}
# Test result client 66: 0.930841068426768
# Train result client 67: {'train_loss': 1.1955566831997462}
# Test result client 67: 1.1785180201897254
# Train result client 68: {'train_loss': 1.1355708837509155}
# Test result client 68: 1.1266927123069763
# Train result client 69: {'train_loss': 0.6966151028871537}
# Test result client 69: 0.6926795669964382
# Train result client 70: {'train_loss': 0.5259674290815989}
# Test result client 70: 0.5113131627440453
# Train result client 71: {'train_loss': 1.0847402413686116}
# Test result client 71: 1.0676179690794512
# Train result client 72: {'train_loss': 1.1188423302438524}
# Test result client 72: 1.1229366858800252
# Train result client 73: {'train_loss': 0.8158584648912603}
# Test result client 73: 0.8089806669288211
# Train result client 74: {'train_loss': 0.446692352111523}
# Test result client 74: 0.4473310112953186
# Train result client 75: {'train_loss': 0.6067421197891235}
# Test result client 75: 0.5937375575304031
# Train result client 76: {'train_loss': 1.7019812720162528}
# Test result client 76: 1.6741486257976956
# Train result client 77: {'train_loss': 1.674293496779033}
# Test result client 77: 1.6639426151911418
# Train result client 78: {'train_loss': 1.2448488235473634}
# Test result client 78: 1.2347819089889527
# Train result client 79: {'train_loss': 1.3978928758038416}
# Test result client 79: 1.3908095576546409
# Train result client 80: {'train_loss': 1.241492509841919}
# Test result client 80: 1.2312533096833662
# Train result client 81: {'train_loss': 0.3447876808544}
# Test result client 81: 0.3371174670755863
# Train result client 82: {'train_loss': 0.8275700258581262}
# Test result client 82: 0.8120470146338145
# Train result client 83: {'train_loss': 1.7278049771602337}
# Test result client 83: 1.6504586272769504
# Train result client 84: {'train_loss': 0.8822441784044107}
# Test result client 84: 0.8694413820902507
# Train result client 85: {'train_loss': 1.0646527138623325}
# Test result client 85: 1.031272221695293
# Train result client 86: {'train_loss': 0.4917882075533271}
# Test result client 86: 0.49009665846824646
# Train result client 87: {'train_loss': 0.9823830509797121}
# Test result client 87: 0.9552144270676833
# Train result client 88: {'train_loss': 0.6730172087748846}
# Test result client 88: 0.6685940399765968
# Train result client 89: {'train_loss': 0.6189579507883858}
# Test result client 89: 0.601736307144165
# Aggregating Model!!
# Round 1 metrics:
# Server Loss = 1.096814160279777
# Round 1 finished!
# Round: 2
# Obtaining Weights!!
# Train result client 0: {'train_loss': 0.7021252231938498}
# Test result client 0: 0.7048412967811931
# Train result client 1: {'train_loss': 0.7716107635355708}
# Test result client 1: 0.7678731424467904
# Train result client 2: {'train_loss': 0.7365185819881063}
# Test result client 2: 0.7292035140774467
# Train result client 3: {'train_loss': 0.7004321955499195}
# Test result client 3: 0.7043349891901016
# Train result client 4: {'train_loss': 0.6038429744635956}
# Test result client 4: 0.6050133323669433
# Train result client 5: {'train_loss': 0.7458208415069079}
# Test result client 5: 0.7460419237613678
# Train result client 6: {'train_loss': 0.9613211531388132}
# Test result client 6: 0.9480428795019785
# Train result client 7: {'train_loss': 0.6637066602706909}
# Test result client 7: 0.6353757551738194
# Train result client 8: {'train_loss': 1.2500287294387817}
# Test result client 8: 1.2300885915756226
# Train result client 9: {'train_loss': 0.9471989326617297}
# Test result client 9: 0.9474542737007141
# Train result client 10: {'train_loss': 0.8711628497771498}
# Test result client 10: 0.8680412664132959
# Train result client 11: {'train_loss': 0.7987509071826935}
# Test result client 11: 0.8016750164653944
# Train result client 12: {'train_loss': 1.0179938389704777}
# Test result client 12: 1.019682458468846
# Train result client 13: {'train_loss': 0.957193911075592}
# Test result client 13: 0.9453962047894796
# Train result client 14: {'train_loss': 1.0722041428089142}
# Test result client 14: 1.05876978689974
# Train result client 15: {'train_loss': 0.8988282948732376}
# Test result client 15: 0.8942923388983074
# Train result client 16: {'train_loss': 0.9841933606506942}
# Test result client 16: 0.9806567480166754
# Train result client 17: {'train_loss': 0.903119941832314}
# Test result client 17: 0.8950727690349926
# Train result client 18: {'train_loss': 1.1435478528340657}
# Test result client 18: 1.151163759685698
# Train result client 19: {'train_loss': 0.9242660118185956}
# Test result client 19: 0.9229286475615068
# Train result client 20: {'train_loss': 0.9774441674574098}
# Test result client 20: 0.9757199400947207
# Train result client 21: {'train_loss': 0.9737286567687988}
# Test result client 21: 0.975046003406698
# Train result client 22: {'train_loss': 1.1936527639627457}
# Test result client 22: 1.1944266822603014
# Train result client 23: {'train_loss': 1.062363610948835}
# Test result client 23: 1.0675216046246616
# Train result client 24: {'train_loss': 0.13282606564462185}
# Test result client 24: 0.12794808546702066
# Train result client 25: {'train_loss': 0.13535566627979279}
# Test result client 25: 0.1312612642844518
# Train result client 26: {'train_loss': 0.13225273415446281}
# Test result client 26: 0.12765823304653168
# Train result client 27: {'train_loss': 0.12002331577241421}
# Test result client 27: 0.11609558016061783
# Train result client 28: {'train_loss': 0.12953098118305206}
# Test result client 28: 0.12484950323899587
# Train result client 29: {'train_loss': 0.1310513075441122}
# Test result client 29: 0.12652549147605896
# Train result client 30: {'train_loss': 0.14106574867452895}
# Test result client 30: 0.13545445601145426
# Train result client 31: {'train_loss': 0.13531764703137533}
# Test result client 31: 0.13112979382276535
# Train result client 32: {'train_loss': 0.13520252065999167}
# Test result client 32: 0.13186076283454895
# Train result client 33: {'train_loss': 0.1378759103161948}
# Test result client 33: 0.13412119448184967
# Train result client 34: {'train_loss': 0.12296562269330025}
# Test result client 34: 0.1188537006576856
# Train result client 35: {'train_loss': 0.13162844628095627}
# Test result client 35: 0.127352903286616
# Train result client 36: {'train_loss': 0.13432546891272068}
# Test result client 36: 0.12964545687039694
# Train result client 37: {'train_loss': 0.15190495736896992}
# Test result client 37: 0.14744088550408682
# Train result client 38: {'train_loss': 0.12882198207080364}
# Test result client 38: 0.1242821216583252
# Train result client 39: {'train_loss': 0.13093191385269165}
# Test result client 39: 0.1262581596771876
# Train result client 40: {'train_loss': 0.1329831067058775}
# Test result client 40: 0.12777050336201987
# Train result client 41: {'train_loss': 0.12450059668885337}
# Test result client 41: 0.1198312093814214
# Train result client 42: {'train_loss': 0.11527763058741887}
# Test result client 42: 0.11112125217914581
# Train result client 43: {'train_loss': 0.12960312142968178}
# Test result client 43: 0.1247979998588562
# Train result client 44: {'train_loss': 0.1283004693686962}
# Test result client 44: 0.12298810730377834
# Train result client 45: {'train_loss': 0.12023128289729357}
# Test result client 45: 0.11553799360990524
# Train result client 46: {'train_loss': 0.12909449140230814}
# Test result client 46: 0.12421304484208424
# Train result client 47: {'train_loss': 0.12487620694769754}
# Test result client 47: 0.11988575756549835
# Train result client 48: {'train_loss': 0.1091124840080738}
# Test result client 48: 0.10453035930792491
# Train result client 49: {'train_loss': 0.11244133528735903}
# Test result client 49: 0.10825739552577336
# Train result client 50: {'train_loss': 0.12207093089818954}
# Test result client 50: 0.11707204083601634
# Train result client 51: {'train_loss': 0.1394792464044359}
# Test result client 51: 0.13432292143503824
# Train result client 52: {'train_loss': 0.11785568669438362}
# Test result client 52: 0.11303313324848811
# Train result client 53: {'train_loss': 0.11672545803917779}
# Test result client 53: 0.11230108638604482
# Train result client 54: {'train_loss': 1.292022553357211}
# Test result client 54: 1.2986227165568958
# Train result client 55: {'train_loss': 1.0881260083271906}
# Test result client 55: 1.098902940750122
# Train result client 56: {'train_loss': 1.03606757364775}
# Test result client 56: 1.0350570529699326
# Train result client 57: {'train_loss': 1.0513939123887281}
# Test result client 57: 1.0353026390075684
# Train result client 58: {'train_loss': 0.5198427169553695}
# Test result client 58: 0.5138300836086274
# Train result client 59: {'train_loss': 1.0024245659510294}
# Test result client 59: 0.9877641856670379
# Train result client 60: {'train_loss': 1.148924519033993}
# Test result client 60: 1.139176141132008
# Train result client 61: {'train_loss': 1.1379588327624581}
# Test result client 61: 1.129849680832454
# Train result client 62: {'train_loss': 0.6862747371196747}
# Test result client 62: 0.675499701499939
# Train result client 63: {'train_loss': 1.0722673096154864}
# Test result client 63: 1.0785009562969208
# Train result client 64: {'train_loss': 0.7119502267416786}
# Test result client 64: 0.6980903853069652
# Train result client 65: {'train_loss': 1.0420152800423759}
# Test result client 65: 1.0312238281423396
# Train result client 66: {'train_loss': 0.8781465480202123}
# Test result client 66: 0.8745755354563395
# Train result client 67: {'train_loss': 1.125481597014836}
# Test result client 67: 1.1239597247197077
# Train result client 68: {'train_loss': 1.0555788645377526}
# Test result client 68: 1.0459593534469604
# Train result client 69: {'train_loss': 0.6749671280384064}
# Test result client 69: 0.6670446140425546
# Train result client 70: {'train_loss': 0.41115543494621914}
# Test result client 70: 0.39960983395576477
# Train result client 71: {'train_loss': 0.9923645926244331}
# Test result client 71: 0.9902990406209772
# Train result client 72: {'train_loss': 1.0694480405913458}
# Test result client 72: 1.0780226488908131
# Train result client 73: {'train_loss': 0.8023037336089395}
# Test result client 73: 0.796237952179379
# Train result client 74: {'train_loss': 0.4275543231230516}
# Test result client 74: 0.4237716421484947
# Train result client 75: {'train_loss': 0.528294506072998}
# Test result client 75: 0.5151349417865276
# Train result client 76: {'train_loss': 1.5873026549816132}
# Test result client 76: 1.5765073431862726
# Train result client 77: {'train_loss': 1.6106864937714167}
# Test result client 77: 1.6089836888843112
# Train result client 78: {'train_loss': 1.160323174794515}
# Test result client 78: 1.1450120449066161
# Train result client 79: {'train_loss': 1.341538303428226}
# Test result client 79: 1.340855143286965
# Train result client 80: {'train_loss': 1.1939682259279139}
# Test result client 80: 1.1900308782404119
# Train result client 81: {'train_loss': 0.30622687190771103}
# Test result client 81: 0.29559266194701195
# Train result client 82: {'train_loss': 0.747115095979289}
# Test result client 82: 0.7355583359797796
# Train result client 83: {'train_loss': 1.6635713760669415}
# Test result client 83: 1.600208706325955
# Train result client 84: {'train_loss': 0.8410699975987276}
# Test result client 84: 0.8347699562708537
# Train result client 85: {'train_loss': 0.9832518082676511}
# Test result client 85: 0.9644122448834506
# Train result client 86: {'train_loss': 0.45434986893087626}
# Test result client 86: 0.4524669736623764
# Train result client 87: {'train_loss': 0.9134264848171136}
# Test result client 87: 0.8985083653376653
# Train result client 88: {'train_loss': 0.637514109412829}
# Test result client 88: 0.6298110783100128
# Train result client 89: {'train_loss': 0.5596293473944944}
# Test result client 89: 0.5485292022878473
# Aggregating Model!!
# Round 2 metrics:
# Server Loss = 1.0495386906053048
# Round 2 finished!
# Round: 3
# Obtaining Weights!!
# Train result client 0: {'train_loss': 0.7019067985670907}
# Test result client 0: 0.7047279666770588
# Train result client 1: {'train_loss': 0.7711471372575902}
# Test result client 1: 0.7672205453827268
# Train result client 2: {'train_loss': 0.7356229500031807}
# Test result client 2: 0.7289543883367018
# Train result client 3: {'train_loss': 0.6993315551016066}
# Test result client 3: 0.7034513056278229
# Train result client 4: {'train_loss': 0.6000276592713368}
# Test result client 4: 0.6018213701248168
# Train result client 5: {'train_loss': 0.7446021272947914}
# Test result client 5: 0.7453041871388754
# Train result client 6: {'train_loss': 0.9382181544052927}
# Test result client 6: 0.9301917254924774
# Train result client 7: {'train_loss': 0.5874703884124756}
# Test result client 7: 0.5656176039150783
# Train result client 8: {'train_loss': 1.1996464530626934}
# Test result client 8: 1.1887490153312683
# Train result client 9: {'train_loss': 0.9448087697519976}
# Test result client 9: 0.9462723646845136
# Train result client 10: {'train_loss': 0.8692718553093245}
# Test result client 10: 0.8665362000465393
# Train result client 11: {'train_loss': 0.7981950988372167}
# Test result client 11: 0.8008536748264147
# Train result client 12: {'train_loss': 1.0170006403556238}
# Test result client 12: 1.019031286239624
# Train result client 13: {'train_loss': 0.9566234296018427}
# Test result client 13: 0.9449368814627329
# Train result client 14: {'train_loss': 1.0715290237875545}
# Test result client 14: 1.0582831637425856
# Train result client 15: {'train_loss': 0.8970182955265045}
# Test result client 15: 0.8930810689926147
# Train result client 16: {'train_loss': 0.9841143349548439}
# Test result client 16: 0.9798629954457283
# Train result client 17: {'train_loss': 0.9033348224532436}
# Test result client 17: 0.8947513916275718
# Train result client 18: {'train_loss': 1.1420582298076514}
# Test result client 18: 1.1499902520860945
# Train result client 19: {'train_loss': 0.9230887639349785}
# Test result client 19: 0.9220994412899017
# Train result client 20: {'train_loss': 0.9754372603857695}
# Test result client 20: 0.974416508561089
# Train result client 21: {'train_loss': 0.9735193952270176}
# Test result client 21: 0.9746576764366843
# Train result client 22: {'train_loss': 1.1931004226207733}
# Test result client 22: 1.193879200352563
# Train result client 23: {'train_loss': 1.06096921477999}
# Test result client 23: 1.0664707909930835
# Train result client 24: {'train_loss': 0.09297433774918318}
# Test result client 24: 0.0899274895588557
# Train result client 25: {'train_loss': 0.09379606693983078}
# Test result client 25: 0.09123885879913966
# Train result client 26: {'train_loss': 0.09226190485060215}
# Test result client 26: 0.08950936049222946
# Train result client 27: {'train_loss': 0.08223376888781786}
# Test result client 27: 0.0799546018242836
# Train result client 28: {'train_loss': 0.08899928948708943}
# Test result client 28: 0.08597599218289058
# Train result client 29: {'train_loss': 0.0911746583878994}
# Test result client 29: 0.08846129973729451
# Train result client 30: {'train_loss': 0.09875344272170748}
# Test result client 30: 0.09494330734014511
# Train result client 31: {'train_loss': 0.09371119844061988}
# Test result client 31: 0.0913027748465538
# Train result client 32: {'train_loss': 0.09389219858816691}
# Test result client 32: 0.09208053598801295
# Train result client 33: {'train_loss': 0.0957079827785492}
# Test result client 33: 0.09361847986777623
# Train result client 34: {'train_loss': 0.08472016919404268}
# Test result client 34: 0.08227672676245372
# Train result client 35: {'train_loss': 0.09185045212507248}
# Test result client 35: 0.08935679743687312
# Train result client 36: {'train_loss': 0.09414650779217482}
# Test result client 36: 0.09135785947243373
# Train result client 37: {'train_loss': 0.10887145344167948}
# Test result client 37: 0.10628886024157207
# Train result client 38: {'train_loss': 0.08936008531600237}
# Test result client 38: 0.08662401139736176
# Train result client 39: {'train_loss': 0.09247678932216433}
# Test result client 39: 0.08983508745829265
# Train result client 40: {'train_loss': 0.0940549381905132}
# Test result client 40: 0.09101445972919464
# Train result client 41: {'train_loss': 0.0870460139380561}
# Test result client 41: 0.0842825248837471
# Train result client 42: {'train_loss': 0.07915139032734765}
# Test result client 42: 0.07646254946788152
# Train result client 43: {'train_loss': 0.08988672308623791}
# Test result client 43: 0.08689776062965393
# Train result client 44: {'train_loss': 0.09141788184642792}
# Test result client 44: 0.08810108155012131
# Train result client 45: {'train_loss': 0.08216199185699224}
# Test result client 45: 0.07945219427347183
# Train result client 46: {'train_loss': 0.09089028752512401}
# Test result client 46: 0.08814085026582082
# Train result client 47: {'train_loss': 0.08731711655855179}
# Test result client 47: 0.0843365266919136
# Train result client 48: {'train_loss': 0.07506573274731636}
# Test result client 48: 0.07237070053815842
# Train result client 49: {'train_loss': 0.07676063643561469}
# Test result client 49: 0.07435820251703262
# Train result client 50: {'train_loss': 0.08494428628020817}
# Test result client 50: 0.08189715941747029
# Train result client 51: {'train_loss': 0.09949328667587704}
# Test result client 51: 0.0963602935274442
# Train result client 52: {'train_loss': 0.08050972409546375}
# Test result client 52: 0.07746587196985881
# Train result client 53: {'train_loss': 0.0805978129307429}
# Test result client 53: 0.07792779803276062
# Train result client 54: {'train_loss': 1.274246577060584}
# Test result client 54: 1.286126819523898
# Train result client 55: {'train_loss': 1.065571936277243}
# Test result client 55: 1.0790087580680847
# Train result client 56: {'train_loss': 1.0237353946033276}
# Test result client 56: 1.0249612927436829
# Train result client 57: {'train_loss': 0.9825326708646921}
# Test result client 57: 0.9714405983686447
# Train result client 58: {'train_loss': 0.4969673829693948}
# Test result client 58: 0.494731542468071
# Train result client 59: {'train_loss': 0.9705315709114075}
# Test result client 59: 0.9589971005916595
# Train result client 60: {'train_loss': 1.134632524322061}
# Test result client 60: 1.1270469968969172
# Train result client 61: {'train_loss': 1.1291031322695992}
# Test result client 61: 1.1218479190553938
# Train result client 62: {'train_loss': 0.6600743617330279}
# Test result client 62: 0.6470678448677063
# Train result client 63: {'train_loss': 1.0574494286587364}
# Test result client 63: 1.0676556030909221
# Train result client 64: {'train_loss': 0.6917750484803143}
# Test result client 64: 0.6843364455483176
# Train result client 65: {'train_loss': 1.0270088127681187}
# Test result client 65: 1.019434766335921
# Train result client 66: {'train_loss': 0.863800900547128}
# Test result client 66: 0.8609066903591156
# Train result client 67: {'train_loss': 1.1053879204250516}
# Test result client 67: 1.1091876121667714
# Train result client 68: {'train_loss': 1.0100102057823768}
# Test result client 68: 1.0013640150427818
# Train result client 69: {'train_loss': 0.633904880285263}
# Test result client 69: 0.6254909719739642
# Train result client 70: {'train_loss': 0.36756453414758045}
# Test result client 70: 0.3631448931992054
# Train result client 71: {'train_loss': 0.9707419222051447}
# Test result client 71: 0.9732799204913053
# Train result client 72: {'train_loss': 1.0578965610928006}
# Test result client 72: 1.068025916814804
# Train result client 73: {'train_loss': 0.7969854474067688}
# Test result client 73: 0.7915493349234263
# Train result client 74: {'train_loss': 0.4103034001130324}
# Test result client 74: 0.40877096354961395
# Train result client 75: {'train_loss': 0.4898629724979401}
# Test result client 75: 0.4829469211399555
# Train result client 76: {'train_loss': 1.5589083135128021}
# Test result client 76: 1.5555308792326186
# Train result client 77: {'train_loss': 1.595912286213466}
# Test result client 77: 1.5965026749504938
# Train result client 78: {'train_loss': 1.096721069018046}
# Test result client 78: 1.0852060317993164
# Train result client 79: {'train_loss': 1.3249684241082933}
# Test result client 79: 1.3308444239876487
# Train result client 80: {'train_loss': 1.1826863955048954}
# Test result client 80: 1.1802059737118809
# Train result client 81: {'train_loss': 0.2788846207161744}
# Test result client 81: 0.27156468480825424
# Train result client 82: {'train_loss': 0.7131666180334593}
# Test result client 82: 0.7080792089303335
# Train result client 83: {'train_loss': 1.6421531851475055}
# Test result client 83: 1.583856635623508
# Train result client 84: {'train_loss': 0.831946574151516}
# Test result client 84: 0.8273835778236389
# Train result client 85: {'train_loss': 0.9617553028193387}
# Test result client 85: 0.9488012194633484
# Train result client 86: {'train_loss': 0.4375872677192092}
# Test result client 86: 0.43772436380386354
# Train result client 87: {'train_loss': 0.895903834929833}
# Test result client 87: 0.8848014244666467
# Train result client 88: {'train_loss': 0.6114985371629397}
# Test result client 88: 0.6053770929574966
# Train result client 89: {'train_loss': 0.5420424570055569}
# Test result client 89: 0.5347557772289623
# Aggregating Model!!
# Round 3 metrics:
# Server Loss = 1.035456340157497
# Round 3 finished!
# Round: 4
# Obtaining Weights!!
# Train result client 0: {'train_loss': 0.7020286730357579}
# Test result client 0: 0.7049139250408519
# Train result client 1: {'train_loss': 0.7705966963696835}
# Test result client 1: 0.7666722110339573
# Train result client 2: {'train_loss': 0.7356188297271729}
# Test result client 2: 0.7291250391439958
# Train result client 3: {'train_loss': 0.7003686645674327}
# Test result client 3: 0.7039653211832047
# Train result client 4: {'train_loss': 0.5985882727405692}
# Test result client 4: 0.600142993927002
# Train result client 5: {'train_loss': 0.7442272736837989}
# Test result client 5: 0.7447303086519241
# Train result client 6: {'train_loss': 0.9296606339906391}
# Test result client 6: 0.923563539981842
# Train result client 7: {'train_loss': 0.5415642231702804}
# Test result client 7: 0.5299076693398612
# Train result client 8: {'train_loss': 1.18104749917984}
# Test result client 8: 1.1741826832294464
# Train result client 9: {'train_loss': 0.9442056075615042}
# Test result client 9: 0.9455079521451678
# Train result client 10: {'train_loss': 0.8678806255448539}
# Test result client 10: 0.8654863168211544
# Train result client 11: {'train_loss': 0.7973640478319592}
# Test result client 11: 0.8003208326256793
# Train result client 12: {'train_loss': 1.0167324781417846}
# Test result client 12: 1.018885314464569
# Train result client 13: {'train_loss': 0.956261487750264}
# Test result client 13: 0.944517562786738
# Train result client 14: {'train_loss': 1.0718516830135794}
# Test result client 14: 1.0579203475605359
# Train result client 15: {'train_loss': 0.896049756805102}
# Test result client 15: 0.8921688261785006
# Train result client 16: {'train_loss': 0.9834051116720423}
# Test result client 16: 0.9793559039632479
# Train result client 17: {'train_loss': 0.9028920615223092}
# Test result client 17: 0.8945947045629675
# Train result client 18: {'train_loss': 1.1411420648748225}
# Test result client 18: 1.1492785726274763
# Train result client 19: {'train_loss': 0.9223174677378889}
# Test result client 19: 0.9214545027776198
# Train result client 20: {'train_loss': 0.9751158249911978}
# Test result client 20: 0.973592684382484
# Train result client 21: {'train_loss': 0.9737327392550482}
# Test result client 21: 0.9745846715840426
# Train result client 22: {'train_loss': 1.1936253607273102}
# Test result client 22: 1.1939891907903883
# Train result client 23: {'train_loss': 1.0601820877620152}
# Test result client 23: 1.0657864592292092
# Train result client 24: {'train_loss': 0.0795164443552494}
# Test result client 24: 0.07699323445558548
# Train result client 25: {'train_loss': 0.07989863625594548}
# Test result client 25: 0.07773106793562572
# Train result client 26: {'train_loss': 0.07887980155646801}
# Test result client 26: 0.07656245430310567
# Train result client 27: {'train_loss': 0.06964243669062853}
# Test result client 27: 0.06786979486544926
# Train result client 28: {'train_loss': 0.07563926066671099}
# Test result client 28: 0.07306790848573048
# Train result client 29: {'train_loss': 0.07779248896986246}
# Test result client 29: 0.07555972536404927
# Train result client 30: {'train_loss': 0.08459982914584023}
# Test result client 30: 0.08130313704411189
# Train result client 31: {'train_loss': 0.08009363072259086}
# Test result client 31: 0.07797485962510109
# Train result client 32: {'train_loss': 0.08015186658927373}
# Test result client 32: 0.07872205227613449
# Train result client 33: {'train_loss': 0.08160348130123955}
# Test result client 33: 0.0799619307120641
# Train result client 34: {'train_loss': 0.07187805138528347}
# Test result client 34: 0.06997505327065785
# Train result client 35: {'train_loss': 0.07851643580943346}
# Test result client 35: 0.0764900694290797
# Train result client 36: {'train_loss': 0.08043719921261072}
# Test result client 36: 0.07834883530934651
# Train result client 37: {'train_loss': 0.0943570164963603}
# Test result client 37: 0.09213832020759583
# Train result client 38: {'train_loss': 0.07619290519505739}
# Test result client 38: 0.0739252616961797
# Train result client 39: {'train_loss': 0.07960872931612863}
# Test result client 39: 0.07741219302018483
# Train result client 40: {'train_loss': 0.08090837465392219}
# Test result client 40: 0.07848134636878967
# Train result client 41: {'train_loss': 0.0743046717511283}
# Test result client 41: 0.07218083490928014
# Train result client 42: {'train_loss': 0.06701439867417018}
# Test result client 42: 0.06482047587633133
# Train result client 43: {'train_loss': 0.07654215022921562}
# Test result client 43: 0.07406422744194667
# Train result client 44: {'train_loss': 0.07840094491839408}
# Test result client 44: 0.07620340337355931
# Train result client 45: {'train_loss': 0.06972862500697374}
# Test result client 45: 0.06737237175305684
# Train result client 46: {'train_loss': 0.07816316932439804}
# Test result client 46: 0.0758634681502978
# Train result client 47: {'train_loss': 0.0746843351258172}
# Test result client 47: 0.07226300239562988
# Train result client 48: {'train_loss': 0.06360709890723229}
# Test result client 48: 0.061456301560004555
# Train result client 49: {'train_loss': 0.064887882106834}
# Test result client 49: 0.06296484172344208
# Train result client 50: {'train_loss': 0.07239448610279295}
# Test result client 50: 0.06998373071352641
# Train result client 51: {'train_loss': 0.08566929565535651}
# Test result client 51: 0.08335902790228526
# Train result client 52: {'train_loss': 0.06816453579813242}
# Test result client 52: 0.06562159955501556
# Train result client 53: {'train_loss': 0.06845926327837838}
# Test result client 53: 0.06631004810333252
# Train result client 54: {'train_loss': 1.2701587062893491}
# Test result client 54: 1.2820513681931929
# Train result client 55: {'train_loss': 1.0551290236986601}
# Test result client 55: 1.0717873871326447
# Train result client 56: {'train_loss': 1.0199167900963833}
# Test result client 56: 1.021866982181867
# Train result client 57: {'train_loss': 0.9449591453258808}
# Test result client 57: 0.9429772198200226
# Train result client 58: {'train_loss': 0.488543628684936}
# Test result client 58: 0.48689364194869994
# Train result client 59: {'train_loss': 0.9556303302447001}
# Test result client 59: 0.9460873007774353
# Train result client 60: {'train_loss': 1.1298532275592579}
# Test result client 60: 1.1219539425589822
# Train result client 61: {'train_loss': 1.125307004560124}
# Test result client 61: 1.1184723036629813
# Train result client 62: {'train_loss': 0.630187622138432}
# Test result client 62: 0.6165040731430054
# Train result client 63: {'train_loss': 1.0525941409562762}
# Test result client 63: 1.0635091662406921
# Train result client 64: {'train_loss': 0.6854909395470339}
# Test result client 64: 0.6796808080239729
# Train result client 65: {'train_loss': 1.0229016712733678}
# Test result client 65: 1.0164080749858508
# Train result client 66: {'train_loss': 0.8552150585149464}
# Test result client 66: 0.8561827888091406
# Train result client 67: {'train_loss': 1.0984727371306646}
# Test result client 67: 1.1038796993402333
# ...
# Test result client 64: 0.6722454591230913
# Train result client 65: {'train_loss': 1.01702664068767}
# Test result client 65: 1.0112016905437817
# Train result client 66: {'train_loss': 0.8433964472067984}
# Test result client 66: 0.8476793418327967
# Train result client 67: {'train_loss': 1.0868477849733262}
# Test result client 67: 1.0958511187480047
# Train result client 68: {'train_loss': 0.956666322854849}
# Test result client 68: 0.9580115005373955
# Train result client 69: {'train_loss': 0.5353976279497147}
# Test result client 69: 0.5431608131953648
# Train result client 70: {'train_loss': 0.3197850411136945}
# Test result client 70: 0.32280372828245163
# Train result client 71: {'train_loss': 0.94724487174641}
# Test result client 71: 0.9545037421313199
# Train result client 72: {'train_loss': 1.054154293404685}
# Test result client 72: 1.0712283849716187
# Train result client 73: {'train_loss': 0.7898869080977007}
# Test result client 73: 0.7873911294672225
# Train result client 74: {'train_loss': 0.3836381481244014}
# Test result client 74: 0.384291909635067
# Train result client 75: {'train_loss': 0.4520742619037628}
# Test result client 75: 0.45385460183024406
# Train result client 76: {'train_loss': 1.5304061216967446}
# Test result client 76: 1.5320739878548517
# Train result client 77: {'train_loss': 1.5786012496267046}
# Test result client 77: 1.58112190829383
# Train result client 78: {'train_loss': 1.020389688014984}
# Test result client 78: 1.0224870681762694
# Train result client 79: {'train_loss': 1.3092552324136097}
# Test result client 79: 1.3237900842319836
# Train result client 80: {'train_loss': 1.1792700115372152}
# Test result client 80: 1.1815715377981013
# Train result client 81: {'train_loss': 0.23743660872181258}
# Test result client 81: 0.23781855776906013
# Train result client 82: {'train_loss': 0.6857725177940569}
# Test result client 82: 0.6869112948576609
# Train result client 83: {'train_loss': 1.608496028643388}
# Test result client 83: 1.5587062040964763
# Train result client 84: {'train_loss': 0.8231169357895851}
# Test result client 84: 0.8205966711044311
# Train result client 85: {'train_loss': 0.9403894904888037}
# Test result client 85: 0.9306231953881003
# Train result client 86: {'train_loss': 0.41606662049889565}
# Test result client 86: 0.4195887088775635
# Train result client 87: {'train_loss': 0.87539476614732}
# Test result client 87: 0.8673330178627601
# Train result client 88: {'train_loss': 0.591659277677536}
# Test result client 88: 0.5872708037495613
# Train result client 89: {'train_loss': 0.5246617566136753}
# Test result client 89: 0.5206001698970795
# Aggregating Model!!
# Round 198 metrics:
# Server Loss = 1.004243093795209
# Round 198 finished!
# Round: 199
# Obtaining Weights!!
# Train result client 0: {'train_loss': 0.696167687858854}
# Test result client 0: 0.6996932517398488
# Train result client 1: {'train_loss': 0.7647380419631502}
# Test result client 1: 0.7619705966540745
# Train result client 2: {'train_loss': 0.7278641831706947}
# Test result client 2: 0.7225908203558489
# Train result client 3: {'train_loss': 0.6854185357926383}
# Test result client 3: 0.69353688955307
# Train result client 4: {'train_loss': 0.6004263388959667}
# Test result client 4: 0.6082132983207703
# Train result client 5: {'train_loss': 0.73971930459926}
# Test result client 5: 0.7409151419997215
# Train result client 6: {'train_loss': 0.9080623984336853}
# Test result client 6: 0.9041323959827423
# Train result client 7: {'train_loss': 0.46230004280805587}
# Test result client 7: 0.46371730736323763
# Train result client 8: {'train_loss': 1.1380139291286469}
# Test result client 8: 1.1359496414661407
# Train result client 9: {'train_loss': 0.9384210802176419}
# Test result client 9: 0.941204601810092
# Train result client 10: {'train_loss': 0.8621691667808676}
# Test result client 10: 0.8597958158044254
# Train result client 11: {'train_loss': 0.7933499291539192}
# Test result client 11: 0.7964700123538142
# Train result client 12: {'train_loss': 1.0101312811558063}
# Test result client 12: 1.0128580047970726
# Train result client 13: {'train_loss': 0.9516195322011972}
# Test result client 13: 0.9407561048865318
# Train result client 14: {'train_loss': 1.0656647051081938}
# Test result client 14: 1.0530330078168348
# Train result client 15: {'train_loss': 0.8906092753012975}
# Test result client 15: 0.887842689689837
# Train result client 16: {'train_loss': 0.9788941957733848}
# Test result client 16: 0.9755370120207468
# Train result client 17: {'train_loss': 0.8981385205833006}
# Test result client 17: 0.890210750428113
# Train result client 18: {'train_loss': 1.1360259561827688}
# Test result client 18: 1.1445323739733015
# Train result client 19: {'train_loss': 0.9178103122158326}
# Test result client 19: 0.9173423106020148
# Train result client 20: {'train_loss': 0.9693477251636449}
# Test result client 20: 0.9691168296904791
# Train result client 21: {'train_loss': 0.9671432989231055}
# Test result client 21: 0.9695817719806324
# Train result client 22: {'train_loss': 1.184772402048111}
# Test result client 22: 1.186748292711046
# Train result client 23: {'train_loss': 1.0556126032556807}
# Test result client 23: 1.0617335438728333
# Train result client 24: {'train_loss': 0.03446385683491826}
# Test result client 24: 0.03419384857018789
# Train result client 25: {'train_loss': 0.03339805081486702}
# Test result client 25: 0.03342912967006365
# Train result client 26: {'train_loss': 0.03464535949751735}
# Test result client 26: 0.034604717046022415
# Train result client 27: {'train_loss': 0.027585183270275593}
# Test result client 27: 0.027611795191963513
# Train result client 28: {'train_loss': 0.03085964678653649}
# Test result client 28: 0.030641794204711914
# Train result client 29: {'train_loss': 0.03409410733729601}
# Test result client 29: 0.034051958471536636
# Train result client 30: {'train_loss': 0.03789018041321209}
# Test result client 30: 0.037269387394189835
# Train result client 31: {'train_loss': 0.034740159554140906}
# Test result client 31: 0.034713851287961006
# Train result client 32: {'train_loss': 0.03432223041142736}
# Test result client 32: 0.0347136619190375
# Train result client 33: {'train_loss': 0.03534473159483501}
# Test result client 33: 0.03558041652043661
# Train result client 34: {'train_loss': 0.02884681848809123}
# Test result client 34: 0.02886020888884862
# Train result client 35: {'train_loss': 0.0347709059715271}
# Test result client 35: 0.03472316265106201
# Train result client 36: {'train_loss': 0.03604247700423002}
# Test result client 36: 0.035897377878427505
# Train result client 37: {'train_loss': 0.04795857844874263}
# Test result client 37: 0.04823818306128184
# Train result client 38: {'train_loss': 0.03324540238827467}
# Test result client 38: 0.03310862307747205
# Train result client 39: {'train_loss': 0.036980184415976204}
# Test result client 39: 0.03721290330092112
# Train result client 40: {'train_loss': 0.038585514658027224}
# Test result client 40: 0.03835957249005636
# Train result client 41: {'train_loss': 0.03267841206656562}
# Test result client 41: 0.03258829936385155
# Train result client 42: {'train_loss': 0.02891429927614}
# Test result client 42: 0.029000643640756607
# Train result client 43: {'train_loss': 0.03324559610337019}
# Test result client 43: 0.03311045095324516
# Train result client 44: {'train_loss': 0.03809062279760837}
# Test result client 44: 0.038045248637596764
# Train result client 45: {'train_loss': 0.028189406264573336}
# Test result client 45: 0.02788621683915456
# Train result client 46: {'train_loss': 0.036662024756272636}
# Test result client 46: 0.03653613105416298
# Train result client 47: {'train_loss': 0.033571540067593254}
# Test result client 47: 0.03337171052893003
# Train result client 48: {'train_loss': 0.025503934547305106}
# Test result client 48: 0.025659757976730663
# Train result client 49: {'train_loss': 0.026053147597445384}
# Test result client 49: 0.02601251130302747
# Train result client 50: {'train_loss': 0.03210419788956642}
# Test result client 50: 0.03183786074320475
# Train result client 51: {'train_loss': 0.0424453719622559}
# Test result client 51: 0.042491008838017784
# Train result client 52: {'train_loss': 0.026617005933076143}
# Test result client 52: 0.026239657153685886
# Train result client 53: {'train_loss': 0.028177109443479113}
# Test result client 53: 0.028147056077917416
# Train result client 54: {'train_loss': 1.2641224210912532}
# Test result client 54: 1.2820321321487427
# Train result client 55: {'train_loss': 1.0458742425991938}
# Test result client 55: 1.0642766505479813
# Train result client 56: {'train_loss': 1.0146372020244598}
# Test result client 56: 1.016342356801033
# Train result client 57: {'train_loss': 0.9048249446428739}
# Test result client 57: 0.9047693908214569
# Train result client 58: {'train_loss': 0.47072272339174825}
# Test result client 58: 0.4731419861316681
# Train result client 59: {'train_loss': 0.9401457667350769}
# Test result client 59: 0.9347254872322083
# Train result client 60: {'train_loss': 1.1198920011520386}
# Test result client 60: 1.142816424369812
# Train result client 61: {'train_loss': 1.1215591782873326}
# Test result client 61: 1.1152539934430803
# Train result client 62: {'train_loss': 0.5615075698920658}
# Test result client 62: 0.5586914777755737
# Train result client 63: {'train_loss': 1.038888758734653}
# Test result client 63: 1.0519617795944214
# Train result client 64: {'train_loss': 0.676653720000211}
# Test result client 64: 0.6723015091635964
# Train result client 65: {'train_loss': 1.0171510679381235}
# Test result client 65: 1.0112000703811646
# Train result client 66: {'train_loss': 0.8457249340258146}
# Test result client 66: 0.8476492365201315
# Train result client 67: {'train_loss': 1.0871620774269104}
# Test result client 67: 1.0962679661237276
# Train result client 68: {'train_loss': 0.9578616137687976}
# Test result client 68: 0.9584018886089325
# Train result client 69: {'train_loss': 0.5354892283678054}
# Test result client 69: 0.543090956551688
# Train result client 70: {'train_loss': 0.31971650446454686}
# Test result client 70: 0.3227747790515423
# Train result client 71: {'train_loss': 0.9475294604445949}
# Test result client 71: 0.954527269710194
# Train result client 72: {'train_loss': 1.0531266033649445}
# Test result client 72: 1.0639586945374806
# Train result client 73: {'train_loss': 0.7901772726665843}
# Test result client 73: 0.7887304657035403
# Train result client 74: {'train_loss': 0.3841871378513483}
# Test result client 74: 0.3857533037662506
# Train result client 75: {'train_loss': 0.4514214324951172}
# Test result client 75: 0.4518030285835266
# Train result client 76: {'train_loss': 1.530423355954034}
# Test result client 76: 1.5320968760384455
# Train result client 77: {'train_loss': 1.579231666667121}
# Test result client 77: 1.5811227692498102
# Train result client 78: {'train_loss': 1.0212379614512126}
# Test result client 78: 1.0232327580451965
# Train result client 79: {'train_loss': 1.309650182723999}
# Test result client 79: 1.3246487270702014
# Train result client 80: {'train_loss': 1.1802505465114819}
# Test result client 80: 1.177782503041354
# Train result client 81: {'train_loss': 0.23812464314202467}
# Test result client 81: 0.23739854991436005
# Train result client 82: {'train_loss': 0.6844843767191234}
# Test result client 82: 0.6870749145746231
# Train result client 83: {'train_loss': 1.608436107635498}
# Test result client 83: 1.559625016318427
# Train result client 84: {'train_loss': 0.8229447416961193}
# Test result client 84: 0.8200102170308431
# Train result client 85: {'train_loss': 0.9406991311998079}
# Test result client 85: 0.9305931438099254
# Train result client 86: {'train_loss': 0.41577740479260683}
# Test result client 86: 0.41952908635139463
# Train result client 87: {'train_loss': 0.8753711550663679}
# Test result client 87: 0.8676807651152978
# Train result client 88: {'train_loss': 0.5897813166181246}
# Test result client 88: 0.5870965421199799
# Train result client 89: {'train_loss': 0.5245336504543529}
# Test result client 89: 0.5207013758746061
# Aggregating Model!!
# Round 199 metrics:
# Server Loss = 1.0040948464151191
# Round 199 finished!
#
#
# --------------------------------------------------
# Loss values all rounds:  [1.1738344299222994, 1.096814160279777, 1.0495386906053048, 1.035456340157497, 1.030658207010639, 1.0280185894688467, 1.0262784799200255, 1.0248609999776022, 1.0236130963018109, 1.0225427298210477, 1.021553593897738, 1.0206450760228758, 1.0198946459333418, 1.0191915657218538, 1.0185565889255062, 1.0179513324484875, 1.017388903707741, 1.0168361487439865, 1.0163170222642752, 1.0158521273769523, 1.0153247102721676, 1.0148714960962195, 1.0144809932195515, 1.0140622925980691, 1.0136487160242906, 1.0133218660713057, 1.0129652142244685, 1.0125995090905924, 1.0123409088828297, 1.0120734769876427, 1.011753030791709, 1.0114925707136715, 1.0112486236001066, 1.0110617803626085, 1.0108224289504502, 1.0105541877465531, 1.0103649484939823, 1.0101346902905672, 1.009965764693831, 1.0098132077850621, 1.0096092519343987, 1.0095253048299182, 1.0092999151693594, 1.0092132034709418, 1.009040321586208, 1.0088907757642465, 1.008761870409606, 1.0085865601702064, 1.008512630702287, 1.0083708520851402, 1.0082524962943888, 1.0081797702861675, 1.008066977321219, 1.0080223756975968, 1.0078515672593766, 1.0077041577471415, 1.0076832237668285, 1.0076210295870596, 1.007544418156215, 1.0074235993078942, 1.0073688326059822, 1.007226661955068, 1.0071807944879851, 1.0071010777009715, 1.007060179584458, 1.0069987130200742, 1.0068541754987557, 1.0068501354426418, 1.0068017471972046, 1.0066784852500454, 1.0067381365797514, 1.0065666675304565, 1.0064434107172393, 1.006426840850867, 1.0063806929602235, 1.0063723378341671, 1.0062835528292526, 1.006294457297051, 1.0061581669277713, 1.0061764388317602, 1.0060868365541609, 1.0060855532680257, 1.0059845316391396, 1.0059647557955735, 1.0059406518223346, 1.0057647220815844, 1.0059001783549717, 1.0057942198975551, 1.0058315765443586, 1.0056602911544212, 1.0057124709689265, 1.005651700626507, 1.0055805332661694, 1.0055220321177214, 1.0055128023673299, 1.005477365649439, 1.005514568180389, 1.005563004909758, 1.0054778676301852, 1.0053553867211102, 1.0053591479405184, 1.0053731129888726, 1.0052528290718725, 1.0052840007736363, 1.0052212914642888, 1.005105258358095, 1.0052073687815652, 1.0050798134203653, 1.0051110409929975, 1.0050897864680015, 1.0050661885869054, 1.00515777585871, 1.0049973305586326, 1.004977863180135, 1.0050069624112583, 1.0049396381376137, 1.004857382832566, 1.0049843059424184, 1.0049253659140411, 1.0047429502689214, 1.0048522075939423, 1.004789487236012, 1.004807751294828, 1.0047378386699664, 1.004746826310432, 1.0046767543466733, 1.0046756188077577, 1.00471307944447, 1.00465263296046, 1.0045955955540944, 1.0046535375398629, 1.0046194587242292, 1.0046020573119638, 1.0046361868390665, 1.004681642733701, 1.004515962603084, 1.0044731273822878, 1.0044630692342555, 1.0045267457995302, 1.0045247549712997, 1.004544348449601, 1.0044772157526165, 1.0043820963752432, 1.0044889631755396, 1.0044966259746386, 1.00431912443293, 1.004477706154414, 1.0043441251658565, 1.0044358181332265, 1.0043174106805905, 1.0044259243562037, 1.0043347969074183, 1.004401006899214, 1.0042984905463892, 1.0043679782038806, 1.004291125779, 1.0043831087716755, 1.0042934290988366, 1.004212992524639, 1.0043246447488428, 1.0042349888406406, 1.0042529300466214, 1.004374250956304, 1.0043885457734651, 1.0042797953382576, 1.004180496965868, 1.004232433855805, 1.0041775228010155, 1.0043663154472862, 1.00406747872693, 1.0040745641102755, 1.0040751277916729, 1.0042662657415473, 1.0042293471685166, 1.0041256112540842, 1.004050916260223, 1.0039945978603426, 1.0043277770645729, 1.0042811649297798, 1.0040952199836664, 1.0041896028779362, 1.0040991415093592, 1.0042124178073877, 1.0041174994938602, 1.004165834414185, 1.0042410539951099, 1.0042440270313437, 1.004292277428311, 1.0040685833815766, 1.0042205445027161, 1.0042573549659553, 1.004095769256082, 1.004268441697188, 1.004154657117666, 1.0043296722275181, 1.0041656587188024, 1.0041352168260171, 1.0041695856924142, 1.004243093795209, 1.0040948464151191]
#
# Time cost: 192.0min.

# %% [markdown]
# # Fine-Tuned Phase

# %% [markdown]
# ## Model Fine-tuned

# %%
class HARClassifier(nn.Module):
    def __init__(self, input_channels=3, sequence_length=128, num_classes=9):  # Adjust num_classes to 13
        super(HARClassifier, self).__init__()
        
        # Assuming the encoder from the AutoEncoder
        self.autoencoder = HARAutoEncoder(input_channels=input_channels, sequence_length=sequence_length)
        
        # Freeze the autoencoder's parameters
        for param in self.autoencoder.parameters():
            param.requires_grad = False
        
        # Classifier part as described
        self.classifier = nn.Sequential(
            nn.Linear(4096, 32),  # Adjust the first linear layer to have 32 outputs
            nn.ReLU(),
            nn.Linear(32, num_classes),  # Final layer for 13 classes
            nn.LogSoftmax(dim=1)
        )

    def forward(self, x):
        # Use the encoder to get the features
        x = self.autoencoder.encoder(x)
        x = x.view(x.size(0), -1)
        # Classify using the extracted features
        x = self.classifier(x)
        return x

# %%
# load model
model = HARClassifier(input_channels=3, sequence_length=128, num_classes=num_classes)
model_pretained = HARAutoEncoder(input_channels=3, sequence_length=128)

# load the global model
model_pretained.load_state_dict(torch.load(f'AutoEncoder_FL/Model_Global_Filtered_v5/{current_time}/global_model_round_199.pth'))

# transfer encoder wieghts to classifier
model.autoencoder.load_state_dict(model_pretained.state_dict())
print(model)
# Out:
# HARClassifier(
#   (autoencoder): HARAutoEncoder(
#     (encoder): Sequential(
#       (0): Conv1d(3, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU()
#       (2): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#       (3): ReLU()
#       (4): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#       (5): ReLU()
#       (6): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#       (7): ReLU()
#     )
#     (fc_encoder): Linear(in_features=4096, out_features=128, bias=True)
#     (fc_decoder): Linear(in_features=128, out_features=4096, bias=True)
#     (decoder): Sequential(
#       (0): ConvTranspose1d(32, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU()
#       (2): ConvTranspose1d(32, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#       (3): ReLU()
#       (4): ConvTranspose1d(32, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#       (5): ReLU()
#       (6): ConvTranspose1d(32, 3, kernel_size=(5,), stride=(1,), padding=(2,))
#       (7): Sigmoid()
#     )
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=10, bias=True)
#     (3): LogSoftmax(dim=1)
#   )
# )

# %%
num_classes
# Out:
# 10

# %% [markdown]
# ## Data Fine-Tuned

# %%
# combine all client labelled data into one
combined_labelled_data = []
combined_labelled_labels = []
for i in range(numclients):
    for data, labels in clients[i]['labelled']:
        combined_labelled_data.append(data)
        combined_labelled_labels.append(labels)
combined_labelled_data = torch.cat(combined_labelled_data, dim=0)
combined_labelled_labels = torch.cat(combined_labelled_labels, dim=0)
# create dataset and dataloader
combined_labelled_dataset = torch.utils.data.TensorDataset(combined_labelled_data, combined_labelled_labels)
combined_labelled_dataloader = torch.utils.data.DataLoader(combined_labelled_dataset, batch_size=batch_size, shuffle=True)

print(f"combined labelled: {len(combined_labelled_dataloader)}")
# Out:
# combined labelled: 702

# %% [markdown]
# ### Class Weight

# %%
# Count the frequency of each class
class_counts = torch.zeros(num_classes)  # num_classes should be defined based on your dataset
for _, target in combined_labelled_dataloader:
    class_counts += torch.bincount(target, minlength=num_classes)

# Calculate class weights
class_counts += 1  # Add 1 to each class count to avoid division by zero
c_weight = 1. / class_counts
c_weight = c_weight / c_weight.sum() * num_classes
c_weight = c_weight.to(device)

# %%
class_counts
# Out:
# tensor([1.6370e+03, 2.1890e+03, 2.1580e+03, 8.5930e+03, 1.3880e+03, 4.7600e+02,
#         1.0000e+00, 1.4910e+03, 2.2450e+03, 2.2650e+03])

# %% [markdown]
# ## Fine-Tuning

# %%
def fine_tune_model(model, train_loader, num_epochs=100, learning_rate=5e-5):
    # Assuming class weights are calculated and provided as `class_weights`
    class_weights = torch.tensor(c_weight).to(device)
    criterion = torch.nn.CrossEntropyLoss()
    
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    
    model.train()
    for epoch in range(num_epochs):
        for data, target in train_loader:
            data, target = data.to(device), target.to(device)
            data = data.permute(0, 2, 1)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
        print(f'Epoch {epoch+1}/{num_epochs}, Loss: {loss.item()}')

# %%
fine_tune_model(model.to(device), combined_labelled_dataloader, num_epochs=200, learning_rate=0.00005)
# Out:
# C:\Users\IME-LAB\AppData\Local\Temp\ipykernel_5040\2825244310.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   class_weights = torch.tensor(c_weight).to(device)
# Epoch 1/200, Loss: 2.295898914337158
# Epoch 2/200, Loss: 2.2201061248779297
# Epoch 3/200, Loss: 2.008805990219116
# Epoch 4/200, Loss: 2.3112759590148926
# Epoch 5/200, Loss: 2.145843029022217
# Epoch 6/200, Loss: 0.36008426547050476
# Epoch 7/200, Loss: 2.248398780822754
# Epoch 8/200, Loss: 1.9149333238601685
# Epoch 9/200, Loss: 1.6474242210388184
# Epoch 10/200, Loss: 3.6817476749420166
# Epoch 11/200, Loss: 1.3660056591033936
# Epoch 12/200, Loss: 0.4523398280143738
# Epoch 13/200, Loss: 0.34714484214782715
# Epoch 14/200, Loss: 1.8342695236206055
# Epoch 15/200, Loss: 1.7251724004745483
# Epoch 16/200, Loss: 1.7103173732757568
# Epoch 17/200, Loss: 0.4142734408378601
# Epoch 18/200, Loss: 1.8550443649291992
# Epoch 19/200, Loss: 1.9814846515655518
# Epoch 20/200, Loss: 1.3806098699569702
# Epoch 21/200, Loss: 2.6610665321350098
# Epoch 22/200, Loss: 2.736276149749756
# Epoch 23/200, Loss: 0.3567810356616974
# Epoch 24/200, Loss: 0.31937193870544434
# Epoch 25/200, Loss: 0.32020071148872375
# Epoch 26/200, Loss: 1.3497740030288696
# Epoch 27/200, Loss: 2.5511789321899414
# Epoch 28/200, Loss: 1.336153268814087
# Epoch 29/200, Loss: 2.2112114429473877
# Epoch 30/200, Loss: 1.7249176502227783
# Epoch 31/200, Loss: 2.3186964988708496
# Epoch 32/200, Loss: 2.309185028076172
# Epoch 33/200, Loss: 0.3178096115589142
# Epoch 34/200, Loss: 2.0692412853240967
# Epoch 35/200, Loss: 0.31904473900794983
# Epoch 36/200, Loss: 2.0150513648986816
# Epoch 37/200, Loss: 0.33334165811538696
# Epoch 38/200, Loss: 1.4818528890609741
# Epoch 39/200, Loss: 3.6697239875793457
# Epoch 40/200, Loss: 3.4417824745178223
# Epoch 41/200, Loss: 1.991783857345581
# Epoch 42/200, Loss: 3.0017411708831787
# Epoch 43/200, Loss: 2.0245895385742188
# Epoch 44/200, Loss: 1.5640050172805786
# Epoch 45/200, Loss: 1.885369062423706
# Epoch 46/200, Loss: 2.242706537246704
# Epoch 47/200, Loss: 1.2179254293441772
# Epoch 48/200, Loss: 0.27780577540397644
# Epoch 49/200, Loss: 2.801515579223633
# Epoch 50/200, Loss: 2.0177505016326904
# Epoch 51/200, Loss: 0.30933618545532227
# Epoch 52/200, Loss: 2.0011069774627686
# Epoch 53/200, Loss: 2.241089105606079
# Epoch 54/200, Loss: 0.3788714110851288
# Epoch 55/200, Loss: 0.508929967880249
# Epoch 56/200, Loss: 2.6177914142608643
# Epoch 57/200, Loss: 0.810382068157196
# Epoch 58/200, Loss: 0.4416947364807129
# Epoch 59/200, Loss: 2.0842158794403076
# Epoch 60/200, Loss: 1.7301595211029053
# Epoch 61/200, Loss: 0.5952527523040771
# Epoch 62/200, Loss: 0.947053074836731
# Epoch 63/200, Loss: 1.7138046026229858
# Epoch 64/200, Loss: 1.6498887538909912
# Epoch 65/200, Loss: 1.309689998626709
# Epoch 66/200, Loss: 1.7437870502471924
# Epoch 67/200, Loss: 2.1143102645874023
# Epoch 68/200, Loss: 2.2154293060302734
# Epoch 69/200, Loss: 0.4675874710083008
# Epoch 70/200, Loss: 0.39437007904052734
# Epoch 71/200, Loss: 1.159430742263794
# Epoch 72/200, Loss: 0.9935979247093201
# Epoch 73/200, Loss: 1.9519559144973755
# Epoch 74/200, Loss: 1.9476869106292725
# Epoch 75/200, Loss: 0.19901570677757263
# Epoch 76/200, Loss: 1.9436981678009033
# Epoch 77/200, Loss: 2.0033750534057617
# Epoch 78/200, Loss: 2.049468994140625
# Epoch 79/200, Loss: 0.35123106837272644
# Epoch 80/200, Loss: 1.8774185180664062
# Epoch 81/200, Loss: 1.2359027862548828
# Epoch 82/200, Loss: 1.7282822132110596
# Epoch 83/200, Loss: 1.9238728284835815
# Epoch 84/200, Loss: 1.2910945415496826
# Epoch 85/200, Loss: 1.2834936380386353
# Epoch 86/200, Loss: 2.073324203491211
# Epoch 87/200, Loss: 2.310368061065674
# Epoch 88/200, Loss: 1.0733697414398193
# Epoch 89/200, Loss: 4.179952144622803
# Epoch 90/200, Loss: 1.664253830909729
# Epoch 91/200, Loss: 0.5522506237030029
# Epoch 92/200, Loss: 1.3087894916534424
# Epoch 93/200, Loss: 1.0632922649383545
# Epoch 94/200, Loss: 1.2594064474105835
# Epoch 95/200, Loss: 2.8667473793029785
# Epoch 96/200, Loss: 0.3213607966899872
# Epoch 97/200, Loss: 1.3951213359832764
# Epoch 98/200, Loss: 1.6880683898925781
# Epoch 99/200, Loss: 1.8194843530654907
# Epoch 100/200, Loss: 1.981188416481018
# Epoch 101/200, Loss: 0.9529228210449219
# Epoch 102/200, Loss: 1.7500180006027222
# Epoch 103/200, Loss: 1.7304985523223877
# Epoch 104/200, Loss: 0.7305895090103149
# Epoch 105/200, Loss: 0.12189043313264847
# Epoch 106/200, Loss: 1.6177237033843994
# Epoch 107/200, Loss: 1.203173279762268
# Epoch 108/200, Loss: 1.4309279918670654
# Epoch 109/200, Loss: 0.21463905274868011
# Epoch 110/200, Loss: 0.25502654910087585
# Epoch 111/200, Loss: 1.7685892581939697
# Epoch 112/200, Loss: 0.7818526029586792
# Epoch 113/200, Loss: 1.7727023363113403
# Epoch 114/200, Loss: 0.47762155532836914
# Epoch 115/200, Loss: 1.705808162689209
# Epoch 116/200, Loss: 0.23912614583969116
# Epoch 117/200, Loss: 1.6992679834365845
# Epoch 118/200, Loss: 0.4789164960384369
# Epoch 119/200, Loss: 0.4234410524368286
# Epoch 120/200, Loss: 1.3017674684524536
# Epoch 121/200, Loss: 0.14941570162773132
# Epoch 122/200, Loss: 2.2672533988952637
# Epoch 123/200, Loss: 1.518377661705017
# Epoch 124/200, Loss: 1.3165522813796997
# Epoch 125/200, Loss: 0.4704299569129944
# Epoch 126/200, Loss: 1.5015068054199219
# Epoch 127/200, Loss: 1.8539438247680664
# Epoch 128/200, Loss: 0.9073787331581116
# Epoch 129/200, Loss: 2.0751047134399414
# Epoch 130/200, Loss: 0.1500404179096222
# Epoch 131/200, Loss: 2.0818653106689453
# Epoch 132/200, Loss: 0.13856413960456848
# Epoch 133/200, Loss: 1.8745559453964233
# Epoch 134/200, Loss: 0.2784307897090912
# Epoch 135/200, Loss: 2.159442901611328
# Epoch 136/200, Loss: 0.11731753498315811
# Epoch 137/200, Loss: 1.1428608894348145
# Epoch 138/200, Loss: 1.4934550523757935
# Epoch 139/200, Loss: 0.2166760414838791
# Epoch 140/200, Loss: 0.45570504665374756
# Epoch 141/200, Loss: 2.7597508430480957
# Epoch 142/200, Loss: 2.773773670196533
# Epoch 143/200, Loss: 0.12016480416059494
# Epoch 144/200, Loss: 1.6296311616897583
# Epoch 145/200, Loss: 1.5416271686553955
# Epoch 146/200, Loss: 1.6547317504882812
# Epoch 147/200, Loss: 0.46817511320114136
# Epoch 148/200, Loss: 0.5466351509094238
# Epoch 149/200, Loss: 1.7400517463684082
# Epoch 150/200, Loss: 2.400339126586914
# Epoch 151/200, Loss: 1.5282658338546753
# Epoch 152/200, Loss: 0.3860815465450287
# Epoch 153/200, Loss: 2.086106300354004
# Epoch 154/200, Loss: 1.7226955890655518
# Epoch 155/200, Loss: 1.6754841804504395
# Epoch 156/200, Loss: 2.1916561126708984
# Epoch 157/200, Loss: 1.4967405796051025
# Epoch 158/200, Loss: 4.475888252258301
# Epoch 159/200, Loss: 1.822959303855896
# Epoch 160/200, Loss: 0.3979511559009552
# Epoch 161/200, Loss: 1.007265329360962
# Epoch 162/200, Loss: 0.4762788414955139
# Epoch 163/200, Loss: 0.1958787441253662
# Epoch 164/200, Loss: 1.884566068649292
# Epoch 165/200, Loss: 0.8133881092071533
# Epoch 166/200, Loss: 1.6638450622558594
# Epoch 167/200, Loss: 1.1982814073562622
# Epoch 168/200, Loss: 0.6399240493774414
# Epoch 169/200, Loss: 2.247194290161133
# Epoch 170/200, Loss: 0.40219470858573914
# Epoch 171/200, Loss: 0.4550850987434387
# Epoch 172/200, Loss: 2.063157081604004
# Epoch 173/200, Loss: 0.18420223891735077
# Epoch 174/200, Loss: 0.6505994200706482
# Epoch 175/200, Loss: 0.1564478576183319
# Epoch 176/200, Loss: 1.255010724067688
# Epoch 177/200, Loss: 0.07603733241558075
# Epoch 178/200, Loss: 0.28884899616241455
# Epoch 179/200, Loss: 1.16408109664917
# Epoch 180/200, Loss: 0.1960994303226471
# Epoch 181/200, Loss: 1.9068694114685059
# Epoch 182/200, Loss: 0.11014072597026825
# Epoch 183/200, Loss: 0.08923279494047165
# Epoch 184/200, Loss: 0.9868074655532837
# Epoch 185/200, Loss: 2.112522602081299
# Epoch 186/200, Loss: 0.9641678333282471
# Epoch 187/200, Loss: 1.5582478046417236
# Epoch 188/200, Loss: 1.7014925479888916
# Epoch 189/200, Loss: 2.2649099826812744
# Epoch 190/200, Loss: 1.8841540813446045
# Epoch 191/200, Loss: 0.3751890957355499
# Epoch 192/200, Loss: 0.11532685160636902
# Epoch 193/200, Loss: 0.33819305896759033
# Epoch 194/200, Loss: 3.1518540382385254
# Epoch 195/200, Loss: 0.04226412996649742
# Epoch 196/200, Loss: 1.2339848279953003
# Epoch 197/200, Loss: 1.7698662281036377
# Epoch 198/200, Loss: 1.3059052228927612
# Epoch 199/200, Loss: 1.5034867525100708
# Epoch 200/200, Loss: 1.5918768644332886

# %%
# method to test the model and get the accuracy and f1 score
def test_model(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    y_true = []
    y_pred = []
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            data = data.permute(0, 2, 1)
            outputs = model(data)
            _, predicted = torch.max(outputs.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            y_true.extend(target.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())
    accuracy = correct / total
    f1 = f1_score(y_true, y_pred, average='weighted')
    print(f'Accuracy: {accuracy}, F1 Score: {f1}')
    return accuracy, f1

# %%
test_model(model, combined_test_dataloader)
# Out:
# Accuracy: 0.5010686044026501, F1 Score: 0.473309563126767
# (0.5010686044026501, 0.473309563126767)

# %% [markdown]
# weight - 30 | 27.99
