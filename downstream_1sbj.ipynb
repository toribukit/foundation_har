# %%
# import libraries
import os
import sys
import time
import pandas as pd
import numpy as np
from scipy import stats
from scipy.interpolate import CubicSpline
from scipy.stats import mode
from sklearn.preprocessing import LabelEncoder

# %%
BATCH_SIZE = 256
train_rate = 0.1

# %%
# load data without header
data = pd.read_csv('./ISWC21_data_plus_raw/rwhar_3sbjs_data.csv', header=None)
# add header
data.columns = ['subject', 'x', 'y', 'z', 'activity']
data.head()
# Out:
#    subject         x          y         z     activity
# 0        0  0.378284  10.168175  0.847547  climbing_up
# 1        0  0.383671  10.172364  0.849942  climbing_up
# 2        0  0.372298  10.181941  0.859518  climbing_up
# 3        0  0.342969  10.170568  0.834379  climbing_up
# 4        0  0.319626  10.159795  0.818817  climbing_up

# %%
data.shape
# Out:
# (659260, 5)

# %%
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(data['activity'])
data['encoded_activity'] = encoded_labels

# %%
data.head()
# Out:
#    subject         x          y         z     activity  encoded_activity
# 0        0  0.378284  10.168175  0.847547  climbing_up                 1
# 1        0  0.383671  10.172364  0.849942  climbing_up                 1
# 2        0  0.372298  10.181941  0.859518  climbing_up                 1
# 3        0  0.342969  10.170568  0.834379  climbing_up                 1
# 4        0  0.319626  10.159795  0.818817  climbing_up                 1

# %%
def sliding_window_samples(data, samples_per_window, overlap_ratio):
    """
    Return a sliding window measured in number of samples over a data array along with the mode label for each window.

    :param data: input array, can be numpy or pandas dataframe
    :param samples_per_window: window length as number of samples
    :param overlap_ratio: overlap is meant as percentage and should be an integer value
    :return: tuple of windows, indices, and labels
    """
    windows = []
    indices = []
    labels = []
    curr = 0
    win_len = int(samples_per_window)
    if overlap_ratio is not None:
        overlapping_elements = int((overlap_ratio / 100) * win_len)
        if overlapping_elements >= win_len:
            print('Number of overlapping elements exceeds window size.')
            return
    while curr < len(data) - win_len:
        window = data[curr:curr + win_len]
        windows.append(window.iloc[:, :-2])  # Exclude the last two columns (original and encoded labels)
        indices.append([curr, curr + win_len])
        
        # Extract and compute the mode of the encoded labels for the current window
        window_labels = window['encoded_activity']
        mode_result = mode(window_labels)
        window_label = mode_result[0] if mode_result[0].size > 0 else mode_result
        labels.append(window_label)

        curr += win_len - overlapping_elements

    result_windows = np.array(windows)
    result_indices = np.array(indices)
    result_labels = np.array(labels)
    return result_windows, result_indices, result_labels

# %%
sampling_rate = 50
time_window = 2
window_size = sampling_rate * time_window
overlap_ratio = 0

window_data, _, window_label = sliding_window_samples(data, window_size, overlap_ratio)
print(f"shape of window dataset (2 sec with 0% overlap): {window_data.shape}")
print(f"shape of window label (2 sec with 0% overlap): {window_label.shape}")
# Out:
# shape of window dataset (2 sec with 0% overlap): (6592, 100, 4)
# shape of window label (2 sec with 0% overlap): (6592,)

# %%
#remove the subject column
window_data = window_data[:, :, 1:]

# %%
window_data[0].shape
# Out:
# (100, 3)

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset, Subset
import numpy as np


window_data = window_data.astype(np.float32)

# Convert to PyTorch tensors
window_data_tensor = torch.from_numpy(window_data)
window_label_tensor = torch.from_numpy(window_label)
#convert labels to long
window_label_tensor = window_label_tensor.long()

# split data into train and test sets
train_size = int(train_rate * len(window_data_tensor))
test_size = len(window_data_tensor) - train_size

# Creating datasets
dataset = TensorDataset(window_data_tensor, window_label_tensor)
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

# Function to extract tensors from Subset
def extract_subset_data(subset, dataset):
    return dataset.tensors[0][subset.indices], dataset.tensors[1][subset.indices]

# Extract data and labels from train and test sets
train_data, train_labels = extract_subset_data(train_dataset, dataset)
test_data, test_labels = extract_subset_data(test_dataset, dataset)

# create train and test TensorDataset
train_dataset = TensorDataset(train_data, train_labels)
test_dataset = TensorDataset(test_data, test_labels)

# create DataLoader for train and test sets
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
#  print the shape of train_loader and test_loader
print(f"shape of train_loader: {len(train_loader)}")
print(f"shape of test_loader: {len(test_loader)}")
# Out:
# shape of train_loader: 3
# shape of test_loader: 24

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class CNNFeatureExtractor(nn.Module):
    def __init__(self, num_classes=4):
        super(CNNFeatureExtractor, self).__init__()

        self.conv1 = nn.Conv1d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(256 * 12, 128)  # Adjust the input features according to your final conv layer output
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))

        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
class TemporalBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride, dilation, padding):
        super(TemporalBlock, self).__init__()
        self.conv1 = nn.Conv1d(in_channels, out_channels, kernel_size,
                               stride=stride, padding=0, dilation=dilation)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv1d(out_channels, out_channels, kernel_size,
                               stride=stride, padding=0, dilation=dilation)
        self.relu2 = nn.ReLU()
        self.downsample = nn.Conv1d(in_channels, out_channels, 1) if in_channels != out_channels else None
        self.relu = nn.ReLU()

    def forward(self, x):
        out = self.conv1(x)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.relu2(out)
        
        res = x if self.downsample is None else self.downsample(x)

        # Adjusting the length of the residual to match the output
        if out.size(2) != res.size(2):
            desired_length = out.size(2)
            res = res[:, :, :desired_length]

        return self.relu(out + res)


class TCN(nn.Module):
    def __init__(self, num_inputs, num_channels, kernel_size, dropout=0.2, num_classes=4):
        super(TCN, self).__init__()
        layers = []
        num_levels = len(num_channels)
        for i in range(num_levels):
            dilation_size = 2 ** i
            in_channels = num_inputs if i == 0 else num_channels[i-1]
            out_channels = num_channels[i]
            layers += [TemporalBlock(in_channels, out_channels, kernel_size, stride=1, dilation=dilation_size,
                                     padding=(kernel_size-1) * dilation_size + (dilation_size - 1))]

        self.tcn = nn.Sequential(*layers)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(num_channels[-1], num_classes)

    def forward(self, x):
        x = self.tcn(x)
        x = F.avg_pool1d(x, x.size(2)).squeeze(2)  # Global Average Pooling
        x = self.dropout(x)
        return self.fc(x)

# %%
# create training function
def train(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    for i, data in enumerate(train_loader):
        inputs, labels = data[0].to(device), data[1].to(device)
        inputs = inputs.transpose(1, 2)
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        # print statistics
        running_loss += loss.item()
    return running_loss / len(train_loader)

# %%
# create testing function
def test(model, test_loader, criterion, device):
    model.eval()
    running_loss = 0.0
    #calculate accuracy
    correct = 0
    with torch.no_grad():
        for i, data in enumerate(test_loader):
            inputs, labels = data[0].to(device), data[1].to(device)
            inputs = inputs.transpose(1, 2)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            #calculate accuracy
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == labels).sum().item()
    accuracy = correct / len(test_loader.dataset)
    return running_loss / len(test_loader), accuracy

# %%
# create function to train and test model
def train_and_test(model, train_loader, test_loader, criterion, optimizer, device, num_epochs):
    train_losses = []
    test_losses = []
    test_accuracies = []
    for epoch in range(num_epochs):
        train_loss = train(model, train_loader, criterion, optimizer, device)
        test_loss, test_accuracy = test(model, test_loader, criterion, device)
        train_losses.append(train_loss)
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)
        print(f"Epoch: {epoch + 1}/{num_epochs}.. Train Loss: {train_loss:.3f}.. Test Loss: {test_loss:.3f}.. Test Accuracy: {test_accuracy:.3f}")
    return train_losses, test_losses, test_accuracies

# %%
# get number of classes
num_classes = len(np.unique(window_label))
print(f"number of classes: {num_classes}")
# Out:
# number of classes: 8

# %%
model = CNNFeatureExtractor(num_classes=num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# train and test model
num_epochs = 50
train_losses, test_losses, test_accuracies = train_and_test(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch: 1/50.. Train Loss: 1.877.. Test Loss: 1.589.. Test Accuracy: 0.446
# Epoch: 2/50.. Train Loss: 1.392.. Test Loss: 1.225.. Test Accuracy: 0.514
# Epoch: 3/50.. Train Loss: 1.114.. Test Loss: 1.060.. Test Accuracy: 0.591
# Epoch: 4/50.. Train Loss: 0.980.. Test Loss: 0.949.. Test Accuracy: 0.691
# Epoch: 5/50.. Train Loss: 0.839.. Test Loss: 0.862.. Test Accuracy: 0.714
# Epoch: 6/50.. Train Loss: 0.760.. Test Loss: 0.829.. Test Accuracy: 0.729
# Epoch: 7/50.. Train Loss: 0.685.. Test Loss: 0.802.. Test Accuracy: 0.780
# Epoch: 8/50.. Train Loss: 0.678.. Test Loss: 0.883.. Test Accuracy: 0.700
# Epoch: 9/50.. Train Loss: 0.683.. Test Loss: 0.809.. Test Accuracy: 0.754
# Epoch: 10/50.. Train Loss: 0.605.. Test Loss: 0.766.. Test Accuracy: 0.752
# Epoch: 11/50.. Train Loss: 0.599.. Test Loss: 0.712.. Test Accuracy: 0.774
# Epoch: 12/50.. Train Loss: 0.528.. Test Loss: 0.703.. Test Accuracy: 0.786
# Epoch: 13/50.. Train Loss: 0.500.. Test Loss: 0.689.. Test Accuracy: 0.789
# Epoch: 14/50.. Train Loss: 0.458.. Test Loss: 0.687.. Test Accuracy: 0.785
# Epoch: 15/50.. Train Loss: 0.424.. Test Loss: 0.660.. Test Accuracy: 0.807
# Epoch: 16/50.. Train Loss: 0.408.. Test Loss: 0.655.. Test Accuracy: 0.810
# Epoch: 17/50.. Train Loss: 0.401.. Test Loss: 0.673.. Test Accuracy: 0.779
# Epoch: 18/50.. Train Loss: 0.373.. Test Loss: 0.642.. Test Accuracy: 0.813
# Epoch: 19/50.. Train Loss: 0.361.. Test Loss: 0.647.. Test Accuracy: 0.797
# Epoch: 20/50.. Train Loss: 0.343.. Test Loss: 0.613.. Test Accuracy: 0.824
# Epoch: 21/50.. Train Loss: 0.309.. Test Loss: 0.628.. Test Accuracy: 0.825
# Epoch: 22/50.. Train Loss: 0.298.. Test Loss: 0.620.. Test Accuracy: 0.820
# Epoch: 23/50.. Train Loss: 0.291.. Test Loss: 0.621.. Test Accuracy: 0.821
# Epoch: 24/50.. Train Loss: 0.299.. Test Loss: 0.667.. Test Accuracy: 0.800
# Epoch: 25/50.. Train Loss: 0.271.. Test Loss: 0.651.. Test Accuracy: 0.824
# Epoch: 26/50.. Train Loss: 0.281.. Test Loss: 0.653.. Test Accuracy: 0.803
# Epoch: 27/50.. Train Loss: 0.245.. Test Loss: 0.605.. Test Accuracy: 0.831
# Epoch: 28/50.. Train Loss: 0.221.. Test Loss: 0.605.. Test Accuracy: 0.837
# Epoch: 29/50.. Train Loss: 0.204.. Test Loss: 0.599.. Test Accuracy: 0.839
# Epoch: 30/50.. Train Loss: 0.210.. Test Loss: 0.606.. Test Accuracy: 0.844
# Epoch: 31/50.. Train Loss: 0.192.. Test Loss: 0.653.. Test Accuracy: 0.837
# Epoch: 32/50.. Train Loss: 0.177.. Test Loss: 0.608.. Test Accuracy: 0.845
# Epoch: 33/50.. Train Loss: 0.163.. Test Loss: 0.609.. Test Accuracy: 0.845
# Epoch: 34/50.. Train Loss: 0.148.. Test Loss: 0.612.. Test Accuracy: 0.851
# Epoch: 35/50.. Train Loss: 0.145.. Test Loss: 0.617.. Test Accuracy: 0.846
# Epoch: 36/50.. Train Loss: 0.135.. Test Loss: 0.652.. Test Accuracy: 0.842
# Epoch: 37/50.. Train Loss: 0.127.. Test Loss: 0.630.. Test Accuracy: 0.846
# Epoch: 38/50.. Train Loss: 0.118.. Test Loss: 0.680.. Test Accuracy: 0.844
# Epoch: 39/50.. Train Loss: 0.114.. Test Loss: 0.638.. Test Accuracy: 0.853
# Epoch: 40/50.. Train Loss: 0.099.. Test Loss: 0.664.. Test Accuracy: 0.851
# Epoch: 41/50.. Train Loss: 0.094.. Test Loss: 0.662.. Test Accuracy: 0.856
# Epoch: 42/50.. Train Loss: 0.094.. Test Loss: 0.688.. Test Accuracy: 0.850
# Epoch: 43/50.. Train Loss: 0.088.. Test Loss: 0.677.. Test Accuracy: 0.857
# Epoch: 44/50.. Train Loss: 0.082.. Test Loss: 0.721.. Test Accuracy: 0.849
# Epoch: 45/50.. Train Loss: 0.080.. Test Loss: 0.704.. Test Accuracy: 0.859
# Epoch: 46/50.. Train Loss: 0.077.. Test Loss: 0.715.. Test Accuracy: 0.856
# Epoch: 47/50.. Train Loss: 0.073.. Test Loss: 0.718.. Test Accuracy: 0.853
# Epoch: 48/50.. Train Loss: 0.066.. Test Loss: 0.713.. Test Accuracy: 0.860
# Epoch: 49/50.. Train Loss: 0.066.. Test Loss: 0.747.. Test Accuracy: 0.855
# Epoch: 50/50.. Train Loss: 0.066.. Test Loss: 0.739.. Test Accuracy: 0.861

# %%
model = CNNFeatureExtractor(num_classes=4)

#load pretrained model
model.load_state_dict(torch.load('./models/cnn_feature_extractor.pt'))

model.fc2 = nn.Linear(in_features=model.fc2.in_features, out_features=num_classes)
model.to(device)

# define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.fc2.parameters(), lr=0.001)

# train and test model
num_epochs = 50
train_losses, test_losses, test_accuracies = train_and_test(model, train_loader, test_loader, criterion, optimizer, device, num_epochs)
# Out:
# Epoch: 1/50.. Train Loss: 2.535.. Test Loss: 2.514.. Test Accuracy: 0.141
# Epoch: 2/50.. Train Loss: 2.443.. Test Loss: 2.418.. Test Accuracy: 0.147
# Epoch: 3/50.. Train Loss: 2.345.. Test Loss: 2.329.. Test Accuracy: 0.146
# Epoch: 4/50.. Train Loss: 2.273.. Test Loss: 2.245.. Test Accuracy: 0.142
# Epoch: 5/50.. Train Loss: 2.194.. Test Loss: 2.166.. Test Accuracy: 0.141
# Epoch: 6/50.. Train Loss: 2.126.. Test Loss: 2.093.. Test Accuracy: 0.215
# Epoch: 7/50.. Train Loss: 2.053.. Test Loss: 2.025.. Test Accuracy: 0.266
# Epoch: 8/50.. Train Loss: 1.991.. Test Loss: 1.965.. Test Accuracy: 0.275
# Epoch: 9/50.. Train Loss: 1.932.. Test Loss: 1.911.. Test Accuracy: 0.282
# Epoch: 10/50.. Train Loss: 1.875.. Test Loss: 1.863.. Test Accuracy: 0.334
# Epoch: 11/50.. Train Loss: 1.833.. Test Loss: 1.820.. Test Accuracy: 0.358
# Epoch: 12/50.. Train Loss: 1.797.. Test Loss: 1.783.. Test Accuracy: 0.369
# Epoch: 13/50.. Train Loss: 1.767.. Test Loss: 1.750.. Test Accuracy: 0.379
# Epoch: 14/50.. Train Loss: 1.734.. Test Loss: 1.721.. Test Accuracy: 0.384
# Epoch: 15/50.. Train Loss: 1.699.. Test Loss: 1.695.. Test Accuracy: 0.390
# Epoch: 16/50.. Train Loss: 1.688.. Test Loss: 1.672.. Test Accuracy: 0.392
# Epoch: 17/50.. Train Loss: 1.645.. Test Loss: 1.650.. Test Accuracy: 0.397
# Epoch: 18/50.. Train Loss: 1.636.. Test Loss: 1.631.. Test Accuracy: 0.400
# Epoch: 19/50.. Train Loss: 1.596.. Test Loss: 1.613.. Test Accuracy: 0.403
# Epoch: 20/50.. Train Loss: 1.582.. Test Loss: 1.596.. Test Accuracy: 0.404
# Epoch: 21/50.. Train Loss: 1.565.. Test Loss: 1.580.. Test Accuracy: 0.405
# Epoch: 22/50.. Train Loss: 1.549.. Test Loss: 1.566.. Test Accuracy: 0.407
# Epoch: 23/50.. Train Loss: 1.531.. Test Loss: 1.552.. Test Accuracy: 0.408
# Epoch: 24/50.. Train Loss: 1.518.. Test Loss: 1.539.. Test Accuracy: 0.411
# Epoch: 25/50.. Train Loss: 1.509.. Test Loss: 1.526.. Test Accuracy: 0.412
# Epoch: 26/50.. Train Loss: 1.495.. Test Loss: 1.513.. Test Accuracy: 0.414
# Epoch: 27/50.. Train Loss: 1.484.. Test Loss: 1.502.. Test Accuracy: 0.416
# Epoch: 28/50.. Train Loss: 1.466.. Test Loss: 1.490.. Test Accuracy: 0.418
# Epoch: 29/50.. Train Loss: 1.443.. Test Loss: 1.479.. Test Accuracy: 0.421
# Epoch: 30/50.. Train Loss: 1.433.. Test Loss: 1.468.. Test Accuracy: 0.423
# Epoch: 31/50.. Train Loss: 1.430.. Test Loss: 1.458.. Test Accuracy: 0.430
# Epoch: 32/50.. Train Loss: 1.414.. Test Loss: 1.448.. Test Accuracy: 0.432
# Epoch: 33/50.. Train Loss: 1.404.. Test Loss: 1.439.. Test Accuracy: 0.435
# Epoch: 34/50.. Train Loss: 1.404.. Test Loss: 1.430.. Test Accuracy: 0.438
# Epoch: 35/50.. Train Loss: 1.403.. Test Loss: 1.420.. Test Accuracy: 0.441
# Epoch: 36/50.. Train Loss: 1.371.. Test Loss: 1.412.. Test Accuracy: 0.444
# Epoch: 37/50.. Train Loss: 1.373.. Test Loss: 1.404.. Test Accuracy: 0.446
# Epoch: 38/50.. Train Loss: 1.356.. Test Loss: 1.395.. Test Accuracy: 0.448
# Epoch: 39/50.. Train Loss: 1.355.. Test Loss: 1.388.. Test Accuracy: 0.451
# Epoch: 40/50.. Train Loss: 1.333.. Test Loss: 1.380.. Test Accuracy: 0.451
# Epoch: 41/50.. Train Loss: 1.333.. Test Loss: 1.373.. Test Accuracy: 0.453
# Epoch: 42/50.. Train Loss: 1.329.. Test Loss: 1.366.. Test Accuracy: 0.454
# Epoch: 43/50.. Train Loss: 1.327.. Test Loss: 1.359.. Test Accuracy: 0.455
# Epoch: 44/50.. Train Loss: 1.312.. Test Loss: 1.353.. Test Accuracy: 0.457
# Epoch: 45/50.. Train Loss: 1.300.. Test Loss: 1.346.. Test Accuracy: 0.459
# Epoch: 46/50.. Train Loss: 1.299.. Test Loss: 1.340.. Test Accuracy: 0.460
# Epoch: 47/50.. Train Loss: 1.296.. Test Loss: 1.334.. Test Accuracy: 0.462
# Epoch: 48/50.. Train Loss: 1.283.. Test Loss: 1.328.. Test Accuracy: 0.464
# Epoch: 49/50.. Train Loss: 1.278.. Test Loss: 1.322.. Test Accuracy: 0.467
# Epoch: 50/50.. Train Loss: 1.273.. Test Loss: 1.317.. Test Accuracy: 0.468

# %%
model = CNNFeatureExtractor(num_classes=4)

#load pretrained model
model.load_state_dict(torch.load('./models/cnn_feature_extractor.pt'))

# Freezing layers up to conv3
for name, param in model.named_parameters():
    if 'conv3' in name:
        break
    param.requires_grad = False

# Unfreeze layers from conv3 onwards
unfreeze = False
for name, param in model.named_parameters():
    if 'conv3' in name:
        unfreeze = True
    if unfreeze:
        param.requires_grad = True

# Update the final classification layer
model.fc2 = nn.Linear(in_features=model.fc2.in_features, out_features=num_classes)

# Move the model to the appropriate device
model.to(device)

# Define the loss function
criterion = nn.CrossEntropyLoss()

# Define the optimizer (only update the parameters that require gradients)
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)

# Train and test the model
num_epochs = 50
train_losses, test_losses, test_accuracies = train_and_test(model, train_loader, test_loader, criterion, optimizer, device, num_epochs)
# Out:
# Epoch: 1/50.. Train Loss: 2.265.. Test Loss: 2.110.. Test Accuracy: 0.091
# Epoch: 2/50.. Train Loss: 2.013.. Test Loss: 1.927.. Test Accuracy: 0.159
# Epoch: 3/50.. Train Loss: 1.835.. Test Loss: 1.794.. Test Accuracy: 0.323
# Epoch: 4/50.. Train Loss: 1.714.. Test Loss: 1.679.. Test Accuracy: 0.434
# Epoch: 5/50.. Train Loss: 1.578.. Test Loss: 1.568.. Test Accuracy: 0.464
# Epoch: 6/50.. Train Loss: 1.447.. Test Loss: 1.452.. Test Accuracy: 0.484
# Epoch: 7/50.. Train Loss: 1.332.. Test Loss: 1.339.. Test Accuracy: 0.515
# Epoch: 8/50.. Train Loss: 1.192.. Test Loss: 1.232.. Test Accuracy: 0.603
# Epoch: 9/50.. Train Loss: 1.075.. Test Loss: 1.129.. Test Accuracy: 0.639
# Epoch: 10/50.. Train Loss: 0.958.. Test Loss: 1.038.. Test Accuracy: 0.663
# Epoch: 11/50.. Train Loss: 0.878.. Test Loss: 0.963.. Test Accuracy: 0.674
# Epoch: 12/50.. Train Loss: 0.790.. Test Loss: 0.897.. Test Accuracy: 0.686
# Epoch: 13/50.. Train Loss: 0.716.. Test Loss: 0.840.. Test Accuracy: 0.739
# Epoch: 14/50.. Train Loss: 0.651.. Test Loss: 0.791.. Test Accuracy: 0.752
# Epoch: 15/50.. Train Loss: 0.594.. Test Loss: 0.743.. Test Accuracy: 0.765
# Epoch: 16/50.. Train Loss: 0.528.. Test Loss: 0.700.. Test Accuracy: 0.775
# Epoch: 17/50.. Train Loss: 0.488.. Test Loss: 0.668.. Test Accuracy: 0.782
# Epoch: 18/50.. Train Loss: 0.451.. Test Loss: 0.642.. Test Accuracy: 0.786
# Epoch: 19/50.. Train Loss: 0.418.. Test Loss: 0.625.. Test Accuracy: 0.794
# Epoch: 20/50.. Train Loss: 0.381.. Test Loss: 0.608.. Test Accuracy: 0.807
# Epoch: 21/50.. Train Loss: 0.343.. Test Loss: 0.594.. Test Accuracy: 0.811
# Epoch: 22/50.. Train Loss: 0.335.. Test Loss: 0.588.. Test Accuracy: 0.815
# Epoch: 23/50.. Train Loss: 0.304.. Test Loss: 0.591.. Test Accuracy: 0.818
# Epoch: 24/50.. Train Loss: 0.298.. Test Loss: 0.586.. Test Accuracy: 0.820
# Epoch: 25/50.. Train Loss: 0.275.. Test Loss: 0.584.. Test Accuracy: 0.822
# Epoch: 26/50.. Train Loss: 0.256.. Test Loss: 0.581.. Test Accuracy: 0.822
# Epoch: 27/50.. Train Loss: 0.241.. Test Loss: 0.579.. Test Accuracy: 0.824
# Epoch: 28/50.. Train Loss: 0.232.. Test Loss: 0.578.. Test Accuracy: 0.826
# Epoch: 29/50.. Train Loss: 0.212.. Test Loss: 0.575.. Test Accuracy: 0.827
# Epoch: 30/50.. Train Loss: 0.194.. Test Loss: 0.575.. Test Accuracy: 0.830
# Epoch: 31/50.. Train Loss: 0.193.. Test Loss: 0.576.. Test Accuracy: 0.830
# Epoch: 32/50.. Train Loss: 0.181.. Test Loss: 0.572.. Test Accuracy: 0.832
# Epoch: 33/50.. Train Loss: 0.172.. Test Loss: 0.567.. Test Accuracy: 0.835
# Epoch: 34/50.. Train Loss: 0.160.. Test Loss: 0.567.. Test Accuracy: 0.835
# Epoch: 35/50.. Train Loss: 0.153.. Test Loss: 0.573.. Test Accuracy: 0.837
# Epoch: 36/50.. Train Loss: 0.150.. Test Loss: 0.575.. Test Accuracy: 0.836
# Epoch: 37/50.. Train Loss: 0.141.. Test Loss: 0.580.. Test Accuracy: 0.835
# Epoch: 38/50.. Train Loss: 0.138.. Test Loss: 0.582.. Test Accuracy: 0.835
# Epoch: 39/50.. Train Loss: 0.134.. Test Loss: 0.582.. Test Accuracy: 0.835
# Epoch: 40/50.. Train Loss: 0.126.. Test Loss: 0.577.. Test Accuracy: 0.838
# Epoch: 41/50.. Train Loss: 0.126.. Test Loss: 0.575.. Test Accuracy: 0.838
# Epoch: 42/50.. Train Loss: 0.112.. Test Loss: 0.577.. Test Accuracy: 0.839
# Epoch: 43/50.. Train Loss: 0.119.. Test Loss: 0.577.. Test Accuracy: 0.841
# Epoch: 44/50.. Train Loss: 0.115.. Test Loss: 0.582.. Test Accuracy: 0.840
# Epoch: 45/50.. Train Loss: 0.107.. Test Loss: 0.592.. Test Accuracy: 0.840
# Epoch: 46/50.. Train Loss: 0.107.. Test Loss: 0.589.. Test Accuracy: 0.839
# Epoch: 47/50.. Train Loss: 0.105.. Test Loss: 0.585.. Test Accuracy: 0.841
# Epoch: 48/50.. Train Loss: 0.105.. Test Loss: 0.587.. Test Accuracy: 0.841
# Epoch: 49/50.. Train Loss: 0.103.. Test Loss: 0.592.. Test Accuracy: 0.841
# Epoch: 50/50.. Train Loss: 0.097.. Test Loss: 0.605.. Test Accuracy: 0.842

# %%
num_inputs = 3  # Assuming 3 input channels (x, y, z axes of the accelerometer)
num_channels = [64, 128, 256]  # Example channel sizes for each layer
kernel_size = 8  # Kernel size for temporal convolutions

model = TCN(num_inputs, num_channels, kernel_size, num_classes=num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# train and test model
num_epochs = 50
train_losses, test_losses, test_accuracies = train_and_test(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=num_epochs)
# Out:
# Epoch: 1/50.. Train Loss: 1.875.. Test Loss: 1.391.. Test Accuracy: 0.565
# Epoch: 2/50.. Train Loss: 1.353.. Test Loss: 1.092.. Test Accuracy: 0.615
# Epoch: 3/50.. Train Loss: 1.106.. Test Loss: 0.989.. Test Accuracy: 0.610
# Epoch: 4/50.. Train Loss: 0.969.. Test Loss: 0.943.. Test Accuracy: 0.675
# Epoch: 5/50.. Train Loss: 0.863.. Test Loss: 0.887.. Test Accuracy: 0.705
# Epoch: 6/50.. Train Loss: 0.814.. Test Loss: 0.867.. Test Accuracy: 0.696
# Epoch: 7/50.. Train Loss: 0.780.. Test Loss: 0.819.. Test Accuracy: 0.713
# Epoch: 8/50.. Train Loss: 0.695.. Test Loss: 0.783.. Test Accuracy: 0.750
# Epoch: 9/50.. Train Loss: 0.662.. Test Loss: 0.809.. Test Accuracy: 0.732
# Epoch: 10/50.. Train Loss: 0.648.. Test Loss: 0.702.. Test Accuracy: 0.788
# Epoch: 11/50.. Train Loss: 0.558.. Test Loss: 0.691.. Test Accuracy: 0.771
# Epoch: 12/50.. Train Loss: 0.535.. Test Loss: 0.684.. Test Accuracy: 0.785
# Epoch: 13/50.. Train Loss: 0.532.. Test Loss: 0.647.. Test Accuracy: 0.810
# Epoch: 14/50.. Train Loss: 0.480.. Test Loss: 0.699.. Test Accuracy: 0.789
# Epoch: 15/50.. Train Loss: 0.489.. Test Loss: 0.691.. Test Accuracy: 0.793
# Epoch: 16/50.. Train Loss: 0.446.. Test Loss: 0.647.. Test Accuracy: 0.796
# Epoch: 17/50.. Train Loss: 0.408.. Test Loss: 0.625.. Test Accuracy: 0.812
# Epoch: 18/50.. Train Loss: 0.377.. Test Loss: 0.652.. Test Accuracy: 0.822
# Epoch: 19/50.. Train Loss: 0.339.. Test Loss: 0.639.. Test Accuracy: 0.823
# Epoch: 20/50.. Train Loss: 0.332.. Test Loss: 0.601.. Test Accuracy: 0.840
# Epoch: 21/50.. Train Loss: 0.357.. Test Loss: 0.579.. Test Accuracy: 0.833
# Epoch: 22/50.. Train Loss: 0.295.. Test Loss: 0.664.. Test Accuracy: 0.815
# Epoch: 23/50.. Train Loss: 0.316.. Test Loss: 0.652.. Test Accuracy: 0.828
# Epoch: 24/50.. Train Loss: 0.280.. Test Loss: 0.602.. Test Accuracy: 0.837
# Epoch: 25/50.. Train Loss: 0.264.. Test Loss: 0.600.. Test Accuracy: 0.843
# Epoch: 26/50.. Train Loss: 0.276.. Test Loss: 0.686.. Test Accuracy: 0.833
# Epoch: 27/50.. Train Loss: 0.250.. Test Loss: 0.687.. Test Accuracy: 0.816
# Epoch: 28/50.. Train Loss: 0.229.. Test Loss: 0.673.. Test Accuracy: 0.838
# Epoch: 29/50.. Train Loss: 0.215.. Test Loss: 0.622.. Test Accuracy: 0.850
# Epoch: 30/50.. Train Loss: 0.209.. Test Loss: 0.649.. Test Accuracy: 0.842
# Epoch: 31/50.. Train Loss: 0.201.. Test Loss: 0.647.. Test Accuracy: 0.851
# Epoch: 32/50.. Train Loss: 0.199.. Test Loss: 0.758.. Test Accuracy: 0.829
# Epoch: 33/50.. Train Loss: 0.198.. Test Loss: 0.606.. Test Accuracy: 0.853
# Epoch: 34/50.. Train Loss: 0.149.. Test Loss: 0.722.. Test Accuracy: 0.835
# Epoch: 35/50.. Train Loss: 0.148.. Test Loss: 0.643.. Test Accuracy: 0.853
# Epoch: 36/50.. Train Loss: 0.141.. Test Loss: 0.670.. Test Accuracy: 0.850
# Epoch: 37/50.. Train Loss: 0.124.. Test Loss: 0.715.. Test Accuracy: 0.847
# Epoch: 38/50.. Train Loss: 0.123.. Test Loss: 0.686.. Test Accuracy: 0.852
# Epoch: 39/50.. Train Loss: 0.128.. Test Loss: 0.724.. Test Accuracy: 0.842
# Epoch: 40/50.. Train Loss: 0.104.. Test Loss: 0.707.. Test Accuracy: 0.852
# Epoch: 41/50.. Train Loss: 0.116.. Test Loss: 0.856.. Test Accuracy: 0.840
# Epoch: 42/50.. Train Loss: 0.114.. Test Loss: 0.812.. Test Accuracy: 0.843
# Epoch: 43/50.. Train Loss: 0.111.. Test Loss: 0.833.. Test Accuracy: 0.842
# Epoch: 44/50.. Train Loss: 0.127.. Test Loss: 0.784.. Test Accuracy: 0.850
# Epoch: 45/50.. Train Loss: 0.105.. Test Loss: 0.715.. Test Accuracy: 0.861
# Epoch: 46/50.. Train Loss: 0.092.. Test Loss: 0.776.. Test Accuracy: 0.855
# Epoch: 47/50.. Train Loss: 0.098.. Test Loss: 0.742.. Test Accuracy: 0.860
# Epoch: 48/50.. Train Loss: 0.085.. Test Loss: 0.714.. Test Accuracy: 0.867
# Epoch: 49/50.. Train Loss: 0.091.. Test Loss: 0.800.. Test Accuracy: 0.851
# Epoch: 50/50.. Train Loss: 0.097.. Test Loss: 0.856.. Test Accuracy: 0.853

# %%
model = TCN(num_inputs, num_channels, kernel_size, num_classes=4)

#load pretrained model
model.load_state_dict(torch.load('./models/tcn_20231216-0131.pt'))

model.fc = nn.Linear(in_features=model.fc.in_features, out_features=num_classes)
model.to(device)

# define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.fc.parameters(), lr=0.001)

# train and test model
num_epochs = 50
train_losses, test_losses, test_accuracies = train_and_test(model, train_loader, test_loader, criterion, optimizer, device, num_epochs)
# Out:
# Epoch: 1/50.. Train Loss: 2.145.. Test Loss: 2.068.. Test Accuracy: 0.146
# Epoch: 2/50.. Train Loss: 2.068.. Test Loss: 2.013.. Test Accuracy: 0.169
# Epoch: 3/50.. Train Loss: 2.004.. Test Loss: 1.965.. Test Accuracy: 0.210
# Epoch: 4/50.. Train Loss: 1.949.. Test Loss: 1.923.. Test Accuracy: 0.266
# Epoch: 5/50.. Train Loss: 1.917.. Test Loss: 1.886.. Test Accuracy: 0.327
# Epoch: 6/50.. Train Loss: 1.873.. Test Loss: 1.852.. Test Accuracy: 0.331
# Epoch: 7/50.. Train Loss: 1.841.. Test Loss: 1.821.. Test Accuracy: 0.340
# Epoch: 8/50.. Train Loss: 1.809.. Test Loss: 1.791.. Test Accuracy: 0.343
# Epoch: 9/50.. Train Loss: 1.784.. Test Loss: 1.763.. Test Accuracy: 0.341
# Epoch: 10/50.. Train Loss: 1.770.. Test Loss: 1.737.. Test Accuracy: 0.390
# Epoch: 11/50.. Train Loss: 1.708.. Test Loss: 1.713.. Test Accuracy: 0.391
# Epoch: 12/50.. Train Loss: 1.702.. Test Loss: 1.689.. Test Accuracy: 0.392
# Epoch: 13/50.. Train Loss: 1.679.. Test Loss: 1.667.. Test Accuracy: 0.399
# Epoch: 14/50.. Train Loss: 1.644.. Test Loss: 1.646.. Test Accuracy: 0.406
# Epoch: 15/50.. Train Loss: 1.632.. Test Loss: 1.626.. Test Accuracy: 0.416
# Epoch: 16/50.. Train Loss: 1.600.. Test Loss: 1.606.. Test Accuracy: 0.423
# Epoch: 17/50.. Train Loss: 1.590.. Test Loss: 1.586.. Test Accuracy: 0.437
# Epoch: 18/50.. Train Loss: 1.560.. Test Loss: 1.567.. Test Accuracy: 0.455
# Epoch: 19/50.. Train Loss: 1.544.. Test Loss: 1.550.. Test Accuracy: 0.481
# Epoch: 20/50.. Train Loss: 1.532.. Test Loss: 1.533.. Test Accuracy: 0.499
# Epoch: 21/50.. Train Loss: 1.533.. Test Loss: 1.517.. Test Accuracy: 0.495
# Epoch: 22/50.. Train Loss: 1.492.. Test Loss: 1.502.. Test Accuracy: 0.504
# Epoch: 23/50.. Train Loss: 1.489.. Test Loss: 1.487.. Test Accuracy: 0.504
# Epoch: 24/50.. Train Loss: 1.464.. Test Loss: 1.472.. Test Accuracy: 0.511
# Epoch: 25/50.. Train Loss: 1.454.. Test Loss: 1.458.. Test Accuracy: 0.516
# Epoch: 26/50.. Train Loss: 1.447.. Test Loss: 1.445.. Test Accuracy: 0.522
# Epoch: 27/50.. Train Loss: 1.432.. Test Loss: 1.433.. Test Accuracy: 0.530
# Epoch: 28/50.. Train Loss: 1.406.. Test Loss: 1.422.. Test Accuracy: 0.535
# Epoch: 29/50.. Train Loss: 1.414.. Test Loss: 1.410.. Test Accuracy: 0.540
# Epoch: 30/50.. Train Loss: 1.399.. Test Loss: 1.399.. Test Accuracy: 0.543
# Epoch: 31/50.. Train Loss: 1.377.. Test Loss: 1.389.. Test Accuracy: 0.545
# Epoch: 32/50.. Train Loss: 1.369.. Test Loss: 1.379.. Test Accuracy: 0.548
# Epoch: 33/50.. Train Loss: 1.371.. Test Loss: 1.370.. Test Accuracy: 0.547
# Epoch: 34/50.. Train Loss: 1.344.. Test Loss: 1.361.. Test Accuracy: 0.547
# Epoch: 35/50.. Train Loss: 1.326.. Test Loss: 1.351.. Test Accuracy: 0.557
# Epoch: 36/50.. Train Loss: 1.337.. Test Loss: 1.343.. Test Accuracy: 0.560
# Epoch: 37/50.. Train Loss: 1.336.. Test Loss: 1.334.. Test Accuracy: 0.574
# Epoch: 38/50.. Train Loss: 1.306.. Test Loss: 1.326.. Test Accuracy: 0.577
# Epoch: 39/50.. Train Loss: 1.313.. Test Loss: 1.318.. Test Accuracy: 0.593
# Epoch: 40/50.. Train Loss: 1.298.. Test Loss: 1.310.. Test Accuracy: 0.606
# Epoch: 41/50.. Train Loss: 1.291.. Test Loss: 1.303.. Test Accuracy: 0.604
# Epoch: 42/50.. Train Loss: 1.293.. Test Loss: 1.296.. Test Accuracy: 0.604
# Epoch: 43/50.. Train Loss: 1.290.. Test Loss: 1.289.. Test Accuracy: 0.606
# Epoch: 44/50.. Train Loss: 1.281.. Test Loss: 1.283.. Test Accuracy: 0.605
# Epoch: 45/50.. Train Loss: 1.268.. Test Loss: 1.276.. Test Accuracy: 0.606
# Epoch: 46/50.. Train Loss: 1.264.. Test Loss: 1.269.. Test Accuracy: 0.598
# Epoch: 47/50.. Train Loss: 1.261.. Test Loss: 1.264.. Test Accuracy: 0.603
# Epoch: 48/50.. Train Loss: 1.245.. Test Loss: 1.257.. Test Accuracy: 0.613
# Epoch: 49/50.. Train Loss: 1.235.. Test Loss: 1.252.. Test Accuracy: 0.616
# Epoch: 50/50.. Train Loss: 1.226.. Test Loss: 1.246.. Test Accuracy: 0.613
